# %% [markdown]
# # Prepare prediction input data (2021)

# %% [markdown]
# import jp2 files (20000 x 20000) collected from "https://maps.psiee.psu.edu/ImageryNavigator/" and read only three band (1,2,3) and split it into tif (2000 x 2000)

# %%
# all dataset split preperation split data into 2000x2000 tiles

import os
import numpy as np
import rasterio
from rasterio.windows import Window

input_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Origin/Jp2"
split_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Origin/Split"

if not os.path.exists(split_folder):
    os.makedirs(split_folder)

# Read only JP2 files from the folder
jp2_files = [os.path.join(input_folder, f) for f in os.listdir(input_folder) if f.endswith('.jp2')]

# Iterate through the JP2 files and split them into 2000x2000 TIF files
for jp2_file in jp2_files:
    with rasterio.open(jp2_file) as src:
        assert src.count >= 4, f"{jp2_file} does not have at least 4 bands"

        width, height = src.width, src.height
        block_size = 2000

        for x in range(0, width, block_size):
            for y in range(0, height, block_size):
                window = Window(x, y, block_size, block_size)
                window_transform = rasterio.windows.transform(window, src.transform)

                # Read only the first three bands
                block_data = src.read([1, 2, 3], window=window)

                # Skip writing empty tiles
                if np.all(block_data == 0):
                    continue

                output_filename = f"split_{os.path.splitext(os.path.basename(jp2_file))[0]}_{x}_{y}.tif"

                with rasterio.open(os.path.join(split_folder, output_filename), 'w', driver='GTiff',
                                   height=block_data.shape[1], width=block_data.shape[2],
                                   count=block_data.shape[0], dtype=block_data.dtype,
                                   crs=src.crs, transform=window_transform) as dest:
                    dest.write(block_data)

print("Operation completed successfully!")

# %% [markdown]
# downsample the whole philly, 2000x2000 image into 512x512

# %%
# resize data to 512x512

import os
import glob
import cv2
import numpy as np
import rasterio

def resize_data(img, new_shape):
    resized_img = cv2.resize(img, (new_shape[1], new_shape[0]), interpolation=cv2.INTER_NEAREST)
    return resized_img

split_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Origin/Split"
resized_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Origin/512"

if not os.path.exists(resized_folder):
    os.makedirs(resized_folder)

split_files = glob.glob(os.path.join(split_folder, '*.tif'))

new_shape = (512, 512)

for i, split_file in enumerate(split_files):
    with rasterio.open(split_file) as src:
        img_data = src.read().transpose(1, 2, 0)
        resized_image = resize_data(img_data, new_shape)
        
        output_filename = f"resized_{i}.tif"
        output_path = os.path.join(resized_folder, output_filename)

        with rasterio.open(output_path, 'w', driver='GTiff',
                           height=resized_image.shape[0], width=resized_image.shape[1],
                           count=resized_image.shape[2], dtype=resized_image.dtype,
                           crs=src.crs, transform=src.transform) as dest:
            dest.write(resized_image.transpose(2, 0, 1))

print("Operation completed successfully!")

# %% [markdown]
# downsample the train(15% of entire philly) data (2000x2000)  to (512x512)

# %%
# resize data to 512x512

import os
import glob
import cv2
import numpy as np
import rasterio

def resize_data(img, new_shape):
    resized_img = cv2.resize(img, (new_shape[1], new_shape[0]), interpolation=cv2.INTER_NEAREST)
    return resized_img

split_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Train/Split-block"
resized_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Train/Split-2021-512"

if not os.path.exists(resized_folder):
    os.makedirs(resized_folder)

split_files = glob.glob(os.path.join(split_folder, '*.tif'))

new_shape = (512, 512)

for i, split_file in enumerate(split_files):
    with rasterio.open(split_file) as src:
        img_data = src.read().transpose(1, 2, 0)
        resized_image = resize_data(img_data, new_shape)
        
        output_filename = f"resized_{i}.tif"
        output_path = os.path.join(resized_folder, output_filename)

        with rasterio.open(output_path, 'w', driver='GTiff',
                           height=resized_image.shape[0], width=resized_image.shape[1],
                           count=resized_image.shape[2], dtype=resized_image.dtype,
                           crs=src.crs, transform=src.transform) as dest:
            dest.write(resized_image.transpose(2, 0, 1))

print("Operation completed successfully!")
# Out:
# Operation completed successfully!

# %% [markdown]
# # Prepare Predction Data (2018)

# %% [markdown]
# Import 2018 philly data (15%) so that we can train this data using model and to do vacant lot change detection from 2018 to 2021

# %%
# resize data to 512x512

import os
import glob
import cv2
import numpy as np
import rasterio

def resize_data(img, new_shape):
    resized_img = cv2.resize(img, (new_shape[1], new_shape[0]), interpolation=cv2.INTER_NEAREST)
    return resized_img

split_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Train/SPLIT2018"
resized_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Origin/2018-512"

if not os.path.exists(resized_folder):
    os.makedirs(resized_folder)

split_files = glob.glob(os.path.join(split_folder, '*.tif'))

new_shape = (512, 512)

for i, split_file in enumerate(split_files):
    with rasterio.open(split_file) as src:
        img_data = src.read().transpose(1, 2, 0)
        resized_image = resize_data(img_data, new_shape)
        
        output_filename = f"resized_{i}.tif"
        output_path = os.path.join(resized_folder, output_filename)

        with rasterio.open(output_path, 'w', driver='GTiff',
                           height=resized_image.shape[0], width=resized_image.shape[1],
                           count=resized_image.shape[2], dtype=resized_image.dtype,
                           crs=src.crs, transform=src.transform) as dest:
            dest.write(resized_image.transpose(2, 0, 1))

print("Operation completed successfully!")
# Out:
# Operation completed successfully!

# %% [markdown]
# # Prepare Train Data

# %% [markdown]
# ### Load all image, label sets

# %% [markdown]
# import 2021 train data (15% of whole philly) and select tiles where label(vacant lots) accounts more than 5% of each tile area

# %%
import os
import rasterio
import numpy as np
import imgaug as ia
import imgaug.augmenters as iaa

def load_tiff_images(folder_path, file_extension=".tif"):
    image_files = sorted([file for file in os.listdir(folder_path) if file.endswith(file_extension)])
    images = []

    count = 0  # Initialize counter variable
    for file in image_files:
        file_path = os.path.join(folder_path, file)
        with rasterio.open(file_path) as src:
            image = src.read().transpose(1, 2, 0)  # Reorder dimensions to (height, width, channels)
            images.append(image)
        count += 1  # Increment counter
        print(f"Loaded image {count} of {len(image_files)}: {file}")  # Print image title with count

    return np.array(images), image_files

def calculate_label_percentage(label):
    total_pixels = label.size
    positive_pixels = np.count_nonzero(label)
    return (positive_pixels / total_pixels) * 100

# Load images and labels
image_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Train/Split-block"
label_folder = "C:/Users/vestalk/Desktop/00_Upenn/30.Spring/03.MUSA6500_Geospatial_Machine_Learning_in_Remote_Sensing/Assignment/Final_Project/60.Data_Preperation/Train-label/Split"
images, image_files = load_tiff_images(image_folder)
labels, label_files = load_tiff_images(label_folder)

# Ensure labels have 4 dimensions
if len(labels.shape) == 3:
    labels = labels[..., np.newaxis]

# Calculate label percentages
label_percentages = [calculate_label_percentage(label) for label in labels]

# Find indices where the label area is more than 5% of the image
selected_indices = [i for i, percentage in enumerate(label_percentages) if percentage > 5]

# Filter images and labels using the selected indices
selected_images = images[selected_indices]
selected_labels = labels[selected_indices]
# Out:
# Loaded image 1 of 1000: split_22002670PAS_PEMA_2021_0_0.tif
# Loaded image 2 of 1000: split_22002670PAS_PEMA_2021_0_10000.tif
# Loaded image 3 of 1000: split_22002670PAS_PEMA_2021_0_12000.tif
# Loaded image 4 of 1000: split_22002670PAS_PEMA_2021_0_14000.tif
# Loaded image 5 of 1000: split_22002670PAS_PEMA_2021_0_16000.tif
# Loaded image 6 of 1000: split_22002670PAS_PEMA_2021_0_18000.tif
# Loaded image 7 of 1000: split_22002670PAS_PEMA_2021_0_2000.tif
# Loaded image 8 of 1000: split_22002670PAS_PEMA_2021_0_4000.tif
# Loaded image 9 of 1000: split_22002670PAS_PEMA_2021_0_6000.tif
# Loaded image 10 of 1000: split_22002670PAS_PEMA_2021_0_8000.tif
# Loaded image 11 of 1000: split_22002670PAS_PEMA_2021_10000_0.tif
# Loaded image 12 of 1000: split_22002670PAS_PEMA_2021_10000_10000.tif
# Loaded image 13 of 1000: split_22002670PAS_PEMA_2021_10000_12000.tif
# Loaded image 14 of 1000: split_22002670PAS_PEMA_2021_10000_14000.tif
# Loaded image 15 of 1000: split_22002670PAS_PEMA_2021_10000_16000.tif
# Loaded image 16 of 1000: split_22002670PAS_PEMA_2021_10000_18000.tif
# Loaded image 17 of 1000: split_22002670PAS_PEMA_2021_10000_2000.tif
# Loaded image 18 of 1000: split_22002670PAS_PEMA_2021_10000_4000.tif
# Loaded image 19 of 1000: split_22002670PAS_PEMA_2021_10000_6000.tif
# Loaded image 20 of 1000: split_22002670PAS_PEMA_2021_10000_8000.tif
# Loaded image 21 of 1000: split_22002670PAS_PEMA_2021_12000_0.tif
# Loaded image 22 of 1000: split_22002670PAS_PEMA_2021_12000_10000.tif
# Loaded image 23 of 1000: split_22002670PAS_PEMA_2021_12000_12000.tif
# Loaded image 24 of 1000: split_22002670PAS_PEMA_2021_12000_14000.tif
# Loaded image 25 of 1000: split_22002670PAS_PEMA_2021_12000_16000.tif
# Loaded image 26 of 1000: split_22002670PAS_PEMA_2021_12000_18000.tif
# Loaded image 27 of 1000: split_22002670PAS_PEMA_2021_12000_2000.tif
# Loaded image 28 of 1000: split_22002670PAS_PEMA_2021_12000_4000.tif
# Loaded image 29 of 1000: split_22002670PAS_PEMA_2021_12000_6000.tif
# Loaded image 30 of 1000: split_22002670PAS_PEMA_2021_12000_8000.tif
# Loaded image 31 of 1000: split_22002670PAS_PEMA_2021_14000_0.tif
# Loaded image 32 of 1000: split_22002670PAS_PEMA_2021_14000_10000.tif
# Loaded image 33 of 1000: split_22002670PAS_PEMA_2021_14000_12000.tif
# Loaded image 34 of 1000: split_22002670PAS_PEMA_2021_14000_14000.tif
# Loaded image 35 of 1000: split_22002670PAS_PEMA_2021_14000_16000.tif
# Loaded image 36 of 1000: split_22002670PAS_PEMA_2021_14000_18000.tif
# Loaded image 37 of 1000: split_22002670PAS_PEMA_2021_14000_2000.tif
# Loaded image 38 of 1000: split_22002670PAS_PEMA_2021_14000_4000.tif
# Loaded image 39 of 1000: split_22002670PAS_PEMA_2021_14000_6000.tif
# Loaded image 40 of 1000: split_22002670PAS_PEMA_2021_14000_8000.tif
# Loaded image 41 of 1000: split_22002670PAS_PEMA_2021_16000_0.tif
# Loaded image 42 of 1000: split_22002670PAS_PEMA_2021_16000_10000.tif
# Loaded image 43 of 1000: split_22002670PAS_PEMA_2021_16000_12000.tif
# Loaded image 44 of 1000: split_22002670PAS_PEMA_2021_16000_14000.tif
# Loaded image 45 of 1000: split_22002670PAS_PEMA_2021_16000_16000.tif
# Loaded image 46 of 1000: split_22002670PAS_PEMA_2021_16000_18000.tif
# Loaded image 47 of 1000: split_22002670PAS_PEMA_2021_16000_2000.tif
# Loaded image 48 of 1000: split_22002670PAS_PEMA_2021_16000_4000.tif
# Loaded image 49 of 1000: split_22002670PAS_PEMA_2021_16000_6000.tif
# Loaded image 50 of 1000: split_22002670PAS_PEMA_2021_16000_8000.tif
# Loaded image 51 of 1000: split_22002670PAS_PEMA_2021_18000_0.tif
# Loaded image 52 of 1000: split_22002670PAS_PEMA_2021_18000_10000.tif
# Loaded image 53 of 1000: split_22002670PAS_PEMA_2021_18000_12000.tif
# Loaded image 54 of 1000: split_22002670PAS_PEMA_2021_18000_14000.tif
# Loaded image 55 of 1000: split_22002670PAS_PEMA_2021_18000_16000.tif
# Loaded image 56 of 1000: split_22002670PAS_PEMA_2021_18000_18000.tif
# Loaded image 57 of 1000: split_22002670PAS_PEMA_2021_18000_2000.tif
# Loaded image 58 of 1000: split_22002670PAS_PEMA_2021_18000_4000.tif
# Loaded image 59 of 1000: split_22002670PAS_PEMA_2021_18000_6000.tif
# Loaded image 60 of 1000: split_22002670PAS_PEMA_2021_18000_8000.tif
# Loaded image 61 of 1000: split_22002670PAS_PEMA_2021_2000_0.tif
# Loaded image 62 of 1000: split_22002670PAS_PEMA_2021_2000_10000.tif
# Loaded image 63 of 1000: split_22002670PAS_PEMA_2021_2000_12000.tif
# Loaded image 64 of 1000: split_22002670PAS_PEMA_2021_2000_14000.tif
# Loaded image 65 of 1000: split_22002670PAS_PEMA_2021_2000_16000.tif
# Loaded image 66 of 1000: split_22002670PAS_PEMA_2021_2000_18000.tif
# Loaded image 67 of 1000: split_22002670PAS_PEMA_2021_2000_2000.tif
# Loaded image 68 of 1000: split_22002670PAS_PEMA_2021_2000_4000.tif
# Loaded image 69 of 1000: split_22002670PAS_PEMA_2021_2000_6000.tif
# Loaded image 70 of 1000: split_22002670PAS_PEMA_2021_2000_8000.tif
# Loaded image 71 of 1000: split_22002670PAS_PEMA_2021_4000_0.tif
# Loaded image 72 of 1000: split_22002670PAS_PEMA_2021_4000_10000.tif
# Loaded image 73 of 1000: split_22002670PAS_PEMA_2021_4000_12000.tif
# Loaded image 74 of 1000: split_22002670PAS_PEMA_2021_4000_14000.tif
# Loaded image 75 of 1000: split_22002670PAS_PEMA_2021_4000_16000.tif
# Loaded image 76 of 1000: split_22002670PAS_PEMA_2021_4000_18000.tif
# Loaded image 77 of 1000: split_22002670PAS_PEMA_2021_4000_2000.tif
# Loaded image 78 of 1000: split_22002670PAS_PEMA_2021_4000_4000.tif
# Loaded image 79 of 1000: split_22002670PAS_PEMA_2021_4000_6000.tif
# Loaded image 80 of 1000: split_22002670PAS_PEMA_2021_4000_8000.tif
# Loaded image 81 of 1000: split_22002670PAS_PEMA_2021_6000_0.tif
# Loaded image 82 of 1000: split_22002670PAS_PEMA_2021_6000_10000.tif
# Loaded image 83 of 1000: split_22002670PAS_PEMA_2021_6000_12000.tif
# Loaded image 84 of 1000: split_22002670PAS_PEMA_2021_6000_14000.tif
# Loaded image 85 of 1000: split_22002670PAS_PEMA_2021_6000_16000.tif
# Loaded image 86 of 1000: split_22002670PAS_PEMA_2021_6000_18000.tif
# Loaded image 87 of 1000: split_22002670PAS_PEMA_2021_6000_2000.tif
# Loaded image 88 of 1000: split_22002670PAS_PEMA_2021_6000_4000.tif
# Loaded image 89 of 1000: split_22002670PAS_PEMA_2021_6000_6000.tif
# Loaded image 90 of 1000: split_22002670PAS_PEMA_2021_6000_8000.tif
# Loaded image 91 of 1000: split_22002670PAS_PEMA_2021_8000_0.tif
# Loaded image 92 of 1000: split_22002670PAS_PEMA_2021_8000_10000.tif
# Loaded image 93 of 1000: split_22002670PAS_PEMA_2021_8000_12000.tif
# Loaded image 94 of 1000: split_22002670PAS_PEMA_2021_8000_14000.tif
# Loaded image 95 of 1000: split_22002670PAS_PEMA_2021_8000_16000.tif
# Loaded image 96 of 1000: split_22002670PAS_PEMA_2021_8000_18000.tif
# Loaded image 97 of 1000: split_22002670PAS_PEMA_2021_8000_2000.tif
# Loaded image 98 of 1000: split_22002670PAS_PEMA_2021_8000_4000.tif
# Loaded image 99 of 1000: split_22002670PAS_PEMA_2021_8000_6000.tif
# Loaded image 100 of 1000: split_22002670PAS_PEMA_2021_8000_8000.tif
# Loaded image 101 of 1000: split_23002670PAS_PEMA_2021_0_0.tif
# Loaded image 102 of 1000: split_23002670PAS_PEMA_2021_0_10000.tif
# Loaded image 103 of 1000: split_23002670PAS_PEMA_2021_0_12000.tif
# Loaded image 104 of 1000: split_23002670PAS_PEMA_2021_0_14000.tif
# Loaded image 105 of 1000: split_23002670PAS_PEMA_2021_0_16000.tif
# Loaded image 106 of 1000: split_23002670PAS_PEMA_2021_0_18000.tif
# Loaded image 107 of 1000: split_23002670PAS_PEMA_2021_0_2000.tif
# Loaded image 108 of 1000: split_23002670PAS_PEMA_2021_0_4000.tif
# Loaded image 109 of 1000: split_23002670PAS_PEMA_2021_0_6000.tif
# Loaded image 110 of 1000: split_23002670PAS_PEMA_2021_0_8000.tif
# Loaded image 111 of 1000: split_23002670PAS_PEMA_2021_10000_0.tif
# Loaded image 112 of 1000: split_23002670PAS_PEMA_2021_10000_10000.tif
# Loaded image 113 of 1000: split_23002670PAS_PEMA_2021_10000_12000.tif
# Loaded image 114 of 1000: split_23002670PAS_PEMA_2021_10000_14000.tif
# Loaded image 115 of 1000: split_23002670PAS_PEMA_2021_10000_16000.tif
# Loaded image 116 of 1000: split_23002670PAS_PEMA_2021_10000_18000.tif
# Loaded image 117 of 1000: split_23002670PAS_PEMA_2021_10000_2000.tif
# Loaded image 118 of 1000: split_23002670PAS_PEMA_2021_10000_4000.tif
# Loaded image 119 of 1000: split_23002670PAS_PEMA_2021_10000_6000.tif
# Loaded image 120 of 1000: split_23002670PAS_PEMA_2021_10000_8000.tif
# Loaded image 121 of 1000: split_23002670PAS_PEMA_2021_12000_0.tif
# Loaded image 122 of 1000: split_23002670PAS_PEMA_2021_12000_10000.tif
# Loaded image 123 of 1000: split_23002670PAS_PEMA_2021_12000_12000.tif
# Loaded image 124 of 1000: split_23002670PAS_PEMA_2021_12000_14000.tif
# Loaded image 125 of 1000: split_23002670PAS_PEMA_2021_12000_16000.tif
# Loaded image 126 of 1000: split_23002670PAS_PEMA_2021_12000_18000.tif
# Loaded image 127 of 1000: split_23002670PAS_PEMA_2021_12000_2000.tif
# Loaded image 128 of 1000: split_23002670PAS_PEMA_2021_12000_4000.tif
# Loaded image 129 of 1000: split_23002670PAS_PEMA_2021_12000_6000.tif
# Loaded image 130 of 1000: split_23002670PAS_PEMA_2021_12000_8000.tif
# Loaded image 131 of 1000: split_23002670PAS_PEMA_2021_14000_0.tif
# Loaded image 132 of 1000: split_23002670PAS_PEMA_2021_14000_10000.tif
# Loaded image 133 of 1000: split_23002670PAS_PEMA_2021_14000_12000.tif
# Loaded image 134 of 1000: split_23002670PAS_PEMA_2021_14000_14000.tif
# Loaded image 135 of 1000: split_23002670PAS_PEMA_2021_14000_16000.tif
# Loaded image 136 of 1000: split_23002670PAS_PEMA_2021_14000_18000.tif
# Loaded image 137 of 1000: split_23002670PAS_PEMA_2021_14000_2000.tif
# Loaded image 138 of 1000: split_23002670PAS_PEMA_2021_14000_4000.tif
# Loaded image 139 of 1000: split_23002670PAS_PEMA_2021_14000_6000.tif
# Loaded image 140 of 1000: split_23002670PAS_PEMA_2021_14000_8000.tif
# Loaded image 141 of 1000: split_23002670PAS_PEMA_2021_16000_0.tif
# Loaded image 142 of 1000: split_23002670PAS_PEMA_2021_16000_10000.tif
# Loaded image 143 of 1000: split_23002670PAS_PEMA_2021_16000_12000.tif
# Loaded image 144 of 1000: split_23002670PAS_PEMA_2021_16000_14000.tif
# Loaded image 145 of 1000: split_23002670PAS_PEMA_2021_16000_16000.tif
# Loaded image 146 of 1000: split_23002670PAS_PEMA_2021_16000_18000.tif
# Loaded image 147 of 1000: split_23002670PAS_PEMA_2021_16000_2000.tif
# Loaded image 148 of 1000: split_23002670PAS_PEMA_2021_16000_4000.tif
# Loaded image 149 of 1000: split_23002670PAS_PEMA_2021_16000_6000.tif
# Loaded image 150 of 1000: split_23002670PAS_PEMA_2021_16000_8000.tif
# Loaded image 151 of 1000: split_23002670PAS_PEMA_2021_18000_0.tif
# Loaded image 152 of 1000: split_23002670PAS_PEMA_2021_18000_10000.tif
# Loaded image 153 of 1000: split_23002670PAS_PEMA_2021_18000_12000.tif
# Loaded image 154 of 1000: split_23002670PAS_PEMA_2021_18000_14000.tif
# Loaded image 155 of 1000: split_23002670PAS_PEMA_2021_18000_16000.tif
# Loaded image 156 of 1000: split_23002670PAS_PEMA_2021_18000_18000.tif
# Loaded image 157 of 1000: split_23002670PAS_PEMA_2021_18000_2000.tif
# Loaded image 158 of 1000: split_23002670PAS_PEMA_2021_18000_4000.tif
# Loaded image 159 of 1000: split_23002670PAS_PEMA_2021_18000_6000.tif
# Loaded image 160 of 1000: split_23002670PAS_PEMA_2021_18000_8000.tif
# Loaded image 161 of 1000: split_23002670PAS_PEMA_2021_2000_0.tif
# Loaded image 162 of 1000: split_23002670PAS_PEMA_2021_2000_10000.tif
# Loaded image 163 of 1000: split_23002670PAS_PEMA_2021_2000_12000.tif
# Loaded image 164 of 1000: split_23002670PAS_PEMA_2021_2000_14000.tif
# Loaded image 165 of 1000: split_23002670PAS_PEMA_2021_2000_16000.tif
# Loaded image 166 of 1000: split_23002670PAS_PEMA_2021_2000_18000.tif
# Loaded image 167 of 1000: split_23002670PAS_PEMA_2021_2000_2000.tif
# Loaded image 168 of 1000: split_23002670PAS_PEMA_2021_2000_4000.tif
# Loaded image 169 of 1000: split_23002670PAS_PEMA_2021_2000_6000.tif
# Loaded image 170 of 1000: split_23002670PAS_PEMA_2021_2000_8000.tif
# Loaded image 171 of 1000: split_23002670PAS_PEMA_2021_4000_0.tif
# Loaded image 172 of 1000: split_23002670PAS_PEMA_2021_4000_10000.tif
# Loaded image 173 of 1000: split_23002670PAS_PEMA_2021_4000_12000.tif
# Loaded image 174 of 1000: split_23002670PAS_PEMA_2021_4000_14000.tif
# Loaded image 175 of 1000: split_23002670PAS_PEMA_2021_4000_16000.tif
# Loaded image 176 of 1000: split_23002670PAS_PEMA_2021_4000_18000.tif
# Loaded image 177 of 1000: split_23002670PAS_PEMA_2021_4000_2000.tif
# Loaded image 178 of 1000: split_23002670PAS_PEMA_2021_4000_4000.tif
# Loaded image 179 of 1000: split_23002670PAS_PEMA_2021_4000_6000.tif
# Loaded image 180 of 1000: split_23002670PAS_PEMA_2021_4000_8000.tif
# Loaded image 181 of 1000: split_23002670PAS_PEMA_2021_6000_0.tif
# Loaded image 182 of 1000: split_23002670PAS_PEMA_2021_6000_10000.tif
# Loaded image 183 of 1000: split_23002670PAS_PEMA_2021_6000_12000.tif
# Loaded image 184 of 1000: split_23002670PAS_PEMA_2021_6000_14000.tif
# Loaded image 185 of 1000: split_23002670PAS_PEMA_2021_6000_16000.tif
# Loaded image 186 of 1000: split_23002670PAS_PEMA_2021_6000_18000.tif
# Loaded image 187 of 1000: split_23002670PAS_PEMA_2021_6000_2000.tif
# Loaded image 188 of 1000: split_23002670PAS_PEMA_2021_6000_4000.tif
# Loaded image 189 of 1000: split_23002670PAS_PEMA_2021_6000_6000.tif
# Loaded image 190 of 1000: split_23002670PAS_PEMA_2021_6000_8000.tif
# Loaded image 191 of 1000: split_23002670PAS_PEMA_2021_8000_0.tif
# Loaded image 192 of 1000: split_23002670PAS_PEMA_2021_8000_10000.tif
# Loaded image 193 of 1000: split_23002670PAS_PEMA_2021_8000_12000.tif
# Loaded image 194 of 1000: split_23002670PAS_PEMA_2021_8000_14000.tif
# Loaded image 195 of 1000: split_23002670PAS_PEMA_2021_8000_16000.tif
# Loaded image 196 of 1000: split_23002670PAS_PEMA_2021_8000_18000.tif
# Loaded image 197 of 1000: split_23002670PAS_PEMA_2021_8000_2000.tif
# Loaded image 198 of 1000: split_23002670PAS_PEMA_2021_8000_4000.tif
# Loaded image 199 of 1000: split_23002670PAS_PEMA_2021_8000_6000.tif
# Loaded image 200 of 1000: split_23002670PAS_PEMA_2021_8000_8000.tif
# Loaded image 201 of 1000: split_23002690PAS_PEMA_2021_0_0.tif
# Loaded image 202 of 1000: split_23002690PAS_PEMA_2021_0_10000.tif
# Loaded image 203 of 1000: split_23002690PAS_PEMA_2021_0_12000.tif
# Loaded image 204 of 1000: split_23002690PAS_PEMA_2021_0_14000.tif
# Loaded image 205 of 1000: split_23002690PAS_PEMA_2021_0_16000.tif
# Loaded image 206 of 1000: split_23002690PAS_PEMA_2021_0_18000.tif
# Loaded image 207 of 1000: split_23002690PAS_PEMA_2021_0_2000.tif
# Loaded image 208 of 1000: split_23002690PAS_PEMA_2021_0_4000.tif
# Loaded image 209 of 1000: split_23002690PAS_PEMA_2021_0_6000.tif
# Loaded image 210 of 1000: split_23002690PAS_PEMA_2021_0_8000.tif
# Loaded image 211 of 1000: split_23002690PAS_PEMA_2021_10000_0.tif
# Loaded image 212 of 1000: split_23002690PAS_PEMA_2021_10000_10000.tif
# Loaded image 213 of 1000: split_23002690PAS_PEMA_2021_10000_12000.tif
# Loaded image 214 of 1000: split_23002690PAS_PEMA_2021_10000_14000.tif
# Loaded image 215 of 1000: split_23002690PAS_PEMA_2021_10000_16000.tif
# Loaded image 216 of 1000: split_23002690PAS_PEMA_2021_10000_18000.tif
# Loaded image 217 of 1000: split_23002690PAS_PEMA_2021_10000_2000.tif
# Loaded image 218 of 1000: split_23002690PAS_PEMA_2021_10000_4000.tif
# Loaded image 219 of 1000: split_23002690PAS_PEMA_2021_10000_6000.tif
# Loaded image 220 of 1000: split_23002690PAS_PEMA_2021_10000_8000.tif
# Loaded image 221 of 1000: split_23002690PAS_PEMA_2021_12000_0.tif
# Loaded image 222 of 1000: split_23002690PAS_PEMA_2021_12000_10000.tif
# Loaded image 223 of 1000: split_23002690PAS_PEMA_2021_12000_12000.tif
# Loaded image 224 of 1000: split_23002690PAS_PEMA_2021_12000_14000.tif
# Loaded image 225 of 1000: split_23002690PAS_PEMA_2021_12000_16000.tif
# Loaded image 226 of 1000: split_23002690PAS_PEMA_2021_12000_18000.tif
# Loaded image 227 of 1000: split_23002690PAS_PEMA_2021_12000_2000.tif
# Loaded image 228 of 1000: split_23002690PAS_PEMA_2021_12000_4000.tif
# Loaded image 229 of 1000: split_23002690PAS_PEMA_2021_12000_6000.tif
# Loaded image 230 of 1000: split_23002690PAS_PEMA_2021_12000_8000.tif
# Loaded image 231 of 1000: split_23002690PAS_PEMA_2021_14000_0.tif
# Loaded image 232 of 1000: split_23002690PAS_PEMA_2021_14000_10000.tif
# Loaded image 233 of 1000: split_23002690PAS_PEMA_2021_14000_12000.tif
# Loaded image 234 of 1000: split_23002690PAS_PEMA_2021_14000_14000.tif
# Loaded image 235 of 1000: split_23002690PAS_PEMA_2021_14000_16000.tif
# Loaded image 236 of 1000: split_23002690PAS_PEMA_2021_14000_18000.tif
# Loaded image 237 of 1000: split_23002690PAS_PEMA_2021_14000_2000.tif
# Loaded image 238 of 1000: split_23002690PAS_PEMA_2021_14000_4000.tif
# Loaded image 239 of 1000: split_23002690PAS_PEMA_2021_14000_6000.tif
# Loaded image 240 of 1000: split_23002690PAS_PEMA_2021_14000_8000.tif
# Loaded image 241 of 1000: split_23002690PAS_PEMA_2021_16000_0.tif
# Loaded image 242 of 1000: split_23002690PAS_PEMA_2021_16000_10000.tif
# Loaded image 243 of 1000: split_23002690PAS_PEMA_2021_16000_12000.tif
# Loaded image 244 of 1000: split_23002690PAS_PEMA_2021_16000_14000.tif
# Loaded image 245 of 1000: split_23002690PAS_PEMA_2021_16000_16000.tif
# Loaded image 246 of 1000: split_23002690PAS_PEMA_2021_16000_18000.tif
# Loaded image 247 of 1000: split_23002690PAS_PEMA_2021_16000_2000.tif
# Loaded image 248 of 1000: split_23002690PAS_PEMA_2021_16000_4000.tif
# Loaded image 249 of 1000: split_23002690PAS_PEMA_2021_16000_6000.tif
# Loaded image 250 of 1000: split_23002690PAS_PEMA_2021_16000_8000.tif
# Loaded image 251 of 1000: split_23002690PAS_PEMA_2021_18000_0.tif
# Loaded image 252 of 1000: split_23002690PAS_PEMA_2021_18000_10000.tif
# Loaded image 253 of 1000: split_23002690PAS_PEMA_2021_18000_12000.tif
# Loaded image 254 of 1000: split_23002690PAS_PEMA_2021_18000_14000.tif
# Loaded image 255 of 1000: split_23002690PAS_PEMA_2021_18000_16000.tif
# Loaded image 256 of 1000: split_23002690PAS_PEMA_2021_18000_18000.tif
# Loaded image 257 of 1000: split_23002690PAS_PEMA_2021_18000_2000.tif
# Loaded image 258 of 1000: split_23002690PAS_PEMA_2021_18000_4000.tif
# Loaded image 259 of 1000: split_23002690PAS_PEMA_2021_18000_6000.tif
# Loaded image 260 of 1000: split_23002690PAS_PEMA_2021_18000_8000.tif
# Loaded image 261 of 1000: split_23002690PAS_PEMA_2021_2000_0.tif
# Loaded image 262 of 1000: split_23002690PAS_PEMA_2021_2000_10000.tif
# Loaded image 263 of 1000: split_23002690PAS_PEMA_2021_2000_12000.tif
# Loaded image 264 of 1000: split_23002690PAS_PEMA_2021_2000_14000.tif
# Loaded image 265 of 1000: split_23002690PAS_PEMA_2021_2000_16000.tif
# Loaded image 266 of 1000: split_23002690PAS_PEMA_2021_2000_18000.tif
# Loaded image 267 of 1000: split_23002690PAS_PEMA_2021_2000_2000.tif
# Loaded image 268 of 1000: split_23002690PAS_PEMA_2021_2000_4000.tif
# Loaded image 269 of 1000: split_23002690PAS_PEMA_2021_2000_6000.tif
# Loaded image 270 of 1000: split_23002690PAS_PEMA_2021_2000_8000.tif
# Loaded image 271 of 1000: split_23002690PAS_PEMA_2021_4000_0.tif
# Loaded image 272 of 1000: split_23002690PAS_PEMA_2021_4000_10000.tif
# Loaded image 273 of 1000: split_23002690PAS_PEMA_2021_4000_12000.tif
# Loaded image 274 of 1000: split_23002690PAS_PEMA_2021_4000_14000.tif
# Loaded image 275 of 1000: split_23002690PAS_PEMA_2021_4000_16000.tif
# Loaded image 276 of 1000: split_23002690PAS_PEMA_2021_4000_18000.tif
# Loaded image 277 of 1000: split_23002690PAS_PEMA_2021_4000_2000.tif
# Loaded image 278 of 1000: split_23002690PAS_PEMA_2021_4000_4000.tif
# Loaded image 279 of 1000: split_23002690PAS_PEMA_2021_4000_6000.tif
# Loaded image 280 of 1000: split_23002690PAS_PEMA_2021_4000_8000.tif
# Loaded image 281 of 1000: split_23002690PAS_PEMA_2021_6000_0.tif
# Loaded image 282 of 1000: split_23002690PAS_PEMA_2021_6000_10000.tif
# Loaded image 283 of 1000: split_23002690PAS_PEMA_2021_6000_12000.tif
# Loaded image 284 of 1000: split_23002690PAS_PEMA_2021_6000_14000.tif
# Loaded image 285 of 1000: split_23002690PAS_PEMA_2021_6000_16000.tif
# Loaded image 286 of 1000: split_23002690PAS_PEMA_2021_6000_18000.tif
# Loaded image 287 of 1000: split_23002690PAS_PEMA_2021_6000_2000.tif
# Loaded image 288 of 1000: split_23002690PAS_PEMA_2021_6000_4000.tif
# Loaded image 289 of 1000: split_23002690PAS_PEMA_2021_6000_6000.tif
# Loaded image 290 of 1000: split_23002690PAS_PEMA_2021_6000_8000.tif
# Loaded image 291 of 1000: split_23002690PAS_PEMA_2021_8000_0.tif
# Loaded image 292 of 1000: split_23002690PAS_PEMA_2021_8000_10000.tif
# Loaded image 293 of 1000: split_23002690PAS_PEMA_2021_8000_12000.tif
# Loaded image 294 of 1000: split_23002690PAS_PEMA_2021_8000_14000.tif
# Loaded image 295 of 1000: split_23002690PAS_PEMA_2021_8000_16000.tif
# Loaded image 296 of 1000: split_23002690PAS_PEMA_2021_8000_18000.tif
# Loaded image 297 of 1000: split_23002690PAS_PEMA_2021_8000_2000.tif
# Loaded image 298 of 1000: split_23002690PAS_PEMA_2021_8000_4000.tif
# Loaded image 299 of 1000: split_23002690PAS_PEMA_2021_8000_6000.tif
# Loaded image 300 of 1000: split_23002690PAS_PEMA_2021_8000_8000.tif
# Loaded image 301 of 1000: split_25002670PAS_PEMA_2021_0_0.tif
# Loaded image 302 of 1000: split_25002670PAS_PEMA_2021_0_10000.tif
# Loaded image 303 of 1000: split_25002670PAS_PEMA_2021_0_12000.tif
# Loaded image 304 of 1000: split_25002670PAS_PEMA_2021_0_14000.tif
# Loaded image 305 of 1000: split_25002670PAS_PEMA_2021_0_16000.tif
# Loaded image 306 of 1000: split_25002670PAS_PEMA_2021_0_18000.tif
# Loaded image 307 of 1000: split_25002670PAS_PEMA_2021_0_2000.tif
# Loaded image 308 of 1000: split_25002670PAS_PEMA_2021_0_4000.tif
# Loaded image 309 of 1000: split_25002670PAS_PEMA_2021_0_6000.tif
# Loaded image 310 of 1000: split_25002670PAS_PEMA_2021_0_8000.tif
# Loaded image 311 of 1000: split_25002670PAS_PEMA_2021_10000_0.tif
# Loaded image 312 of 1000: split_25002670PAS_PEMA_2021_10000_10000.tif
# Loaded image 313 of 1000: split_25002670PAS_PEMA_2021_10000_12000.tif
# Loaded image 314 of 1000: split_25002670PAS_PEMA_2021_10000_14000.tif
# Loaded image 315 of 1000: split_25002670PAS_PEMA_2021_10000_16000.tif
# Loaded image 316 of 1000: split_25002670PAS_PEMA_2021_10000_18000.tif
# Loaded image 317 of 1000: split_25002670PAS_PEMA_2021_10000_2000.tif
# Loaded image 318 of 1000: split_25002670PAS_PEMA_2021_10000_4000.tif
# Loaded image 319 of 1000: split_25002670PAS_PEMA_2021_10000_6000.tif
# Loaded image 320 of 1000: split_25002670PAS_PEMA_2021_10000_8000.tif
# Loaded image 321 of 1000: split_25002670PAS_PEMA_2021_12000_0.tif
# Loaded image 322 of 1000: split_25002670PAS_PEMA_2021_12000_10000.tif
# Loaded image 323 of 1000: split_25002670PAS_PEMA_2021_12000_12000.tif
# Loaded image 324 of 1000: split_25002670PAS_PEMA_2021_12000_14000.tif
# Loaded image 325 of 1000: split_25002670PAS_PEMA_2021_12000_16000.tif
# Loaded image 326 of 1000: split_25002670PAS_PEMA_2021_12000_18000.tif
# Loaded image 327 of 1000: split_25002670PAS_PEMA_2021_12000_2000.tif
# Loaded image 328 of 1000: split_25002670PAS_PEMA_2021_12000_4000.tif
# Loaded image 329 of 1000: split_25002670PAS_PEMA_2021_12000_6000.tif
# Loaded image 330 of 1000: split_25002670PAS_PEMA_2021_12000_8000.tif
# Loaded image 331 of 1000: split_25002670PAS_PEMA_2021_14000_0.tif
# Loaded image 332 of 1000: split_25002670PAS_PEMA_2021_14000_10000.tif
# Loaded image 333 of 1000: split_25002670PAS_PEMA_2021_14000_12000.tif
# Loaded image 334 of 1000: split_25002670PAS_PEMA_2021_14000_14000.tif
# Loaded image 335 of 1000: split_25002670PAS_PEMA_2021_14000_16000.tif
# Loaded image 336 of 1000: split_25002670PAS_PEMA_2021_14000_18000.tif
# Loaded image 337 of 1000: split_25002670PAS_PEMA_2021_14000_2000.tif
# Loaded image 338 of 1000: split_25002670PAS_PEMA_2021_14000_4000.tif
# Loaded image 339 of 1000: split_25002670PAS_PEMA_2021_14000_6000.tif
# Loaded image 340 of 1000: split_25002670PAS_PEMA_2021_14000_8000.tif
# Loaded image 341 of 1000: split_25002670PAS_PEMA_2021_16000_0.tif
# Loaded image 342 of 1000: split_25002670PAS_PEMA_2021_16000_10000.tif
# Loaded image 343 of 1000: split_25002670PAS_PEMA_2021_16000_12000.tif
# Loaded image 344 of 1000: split_25002670PAS_PEMA_2021_16000_14000.tif
# Loaded image 345 of 1000: split_25002670PAS_PEMA_2021_16000_16000.tif
# Loaded image 346 of 1000: split_25002670PAS_PEMA_2021_16000_18000.tif
# Loaded image 347 of 1000: split_25002670PAS_PEMA_2021_16000_2000.tif
# Loaded image 348 of 1000: split_25002670PAS_PEMA_2021_16000_4000.tif
# Loaded image 349 of 1000: split_25002670PAS_PEMA_2021_16000_6000.tif
# Loaded image 350 of 1000: split_25002670PAS_PEMA_2021_16000_8000.tif
# Loaded image 351 of 1000: split_25002670PAS_PEMA_2021_18000_0.tif
# Loaded image 352 of 1000: split_25002670PAS_PEMA_2021_18000_10000.tif
# Loaded image 353 of 1000: split_25002670PAS_PEMA_2021_18000_12000.tif
# Loaded image 354 of 1000: split_25002670PAS_PEMA_2021_18000_14000.tif
# Loaded image 355 of 1000: split_25002670PAS_PEMA_2021_18000_16000.tif
# Loaded image 356 of 1000: split_25002670PAS_PEMA_2021_18000_18000.tif
# Loaded image 357 of 1000: split_25002670PAS_PEMA_2021_18000_2000.tif
# Loaded image 358 of 1000: split_25002670PAS_PEMA_2021_18000_4000.tif
# Loaded image 359 of 1000: split_25002670PAS_PEMA_2021_18000_6000.tif
# Loaded image 360 of 1000: split_25002670PAS_PEMA_2021_18000_8000.tif
# Loaded image 361 of 1000: split_25002670PAS_PEMA_2021_2000_0.tif
# Loaded image 362 of 1000: split_25002670PAS_PEMA_2021_2000_10000.tif
# Loaded image 363 of 1000: split_25002670PAS_PEMA_2021_2000_12000.tif
# Loaded image 364 of 1000: split_25002670PAS_PEMA_2021_2000_14000.tif
# Loaded image 365 of 1000: split_25002670PAS_PEMA_2021_2000_16000.tif
# Loaded image 366 of 1000: split_25002670PAS_PEMA_2021_2000_18000.tif
# Loaded image 367 of 1000: split_25002670PAS_PEMA_2021_2000_2000.tif
# Loaded image 368 of 1000: split_25002670PAS_PEMA_2021_2000_4000.tif
# Loaded image 369 of 1000: split_25002670PAS_PEMA_2021_2000_6000.tif
# Loaded image 370 of 1000: split_25002670PAS_PEMA_2021_2000_8000.tif
# Loaded image 371 of 1000: split_25002670PAS_PEMA_2021_4000_0.tif
# Loaded image 372 of 1000: split_25002670PAS_PEMA_2021_4000_10000.tif
# Loaded image 373 of 1000: split_25002670PAS_PEMA_2021_4000_12000.tif
# Loaded image 374 of 1000: split_25002670PAS_PEMA_2021_4000_14000.tif
# Loaded image 375 of 1000: split_25002670PAS_PEMA_2021_4000_16000.tif
# Loaded image 376 of 1000: split_25002670PAS_PEMA_2021_4000_18000.tif
# Loaded image 377 of 1000: split_25002670PAS_PEMA_2021_4000_2000.tif
# Loaded image 378 of 1000: split_25002670PAS_PEMA_2021_4000_4000.tif
# Loaded image 379 of 1000: split_25002670PAS_PEMA_2021_4000_6000.tif
# Loaded image 380 of 1000: split_25002670PAS_PEMA_2021_4000_8000.tif
# Loaded image 381 of 1000: split_25002670PAS_PEMA_2021_6000_0.tif
# Loaded image 382 of 1000: split_25002670PAS_PEMA_2021_6000_10000.tif
# Loaded image 383 of 1000: split_25002670PAS_PEMA_2021_6000_12000.tif
# Loaded image 384 of 1000: split_25002670PAS_PEMA_2021_6000_14000.tif
# Loaded image 385 of 1000: split_25002670PAS_PEMA_2021_6000_16000.tif
# Loaded image 386 of 1000: split_25002670PAS_PEMA_2021_6000_18000.tif
# Loaded image 387 of 1000: split_25002670PAS_PEMA_2021_6000_2000.tif
# Loaded image 388 of 1000: split_25002670PAS_PEMA_2021_6000_4000.tif
# Loaded image 389 of 1000: split_25002670PAS_PEMA_2021_6000_6000.tif
# Loaded image 390 of 1000: split_25002670PAS_PEMA_2021_6000_8000.tif
# Loaded image 391 of 1000: split_25002670PAS_PEMA_2021_8000_0.tif
# Loaded image 392 of 1000: split_25002670PAS_PEMA_2021_8000_10000.tif
# Loaded image 393 of 1000: split_25002670PAS_PEMA_2021_8000_12000.tif
# Loaded image 394 of 1000: split_25002670PAS_PEMA_2021_8000_14000.tif
# Loaded image 395 of 1000: split_25002670PAS_PEMA_2021_8000_16000.tif
# Loaded image 396 of 1000: split_25002670PAS_PEMA_2021_8000_18000.tif
# Loaded image 397 of 1000: split_25002670PAS_PEMA_2021_8000_2000.tif
# Loaded image 398 of 1000: split_25002670PAS_PEMA_2021_8000_4000.tif
# Loaded image 399 of 1000: split_25002670PAS_PEMA_2021_8000_6000.tif
# Loaded image 400 of 1000: split_25002670PAS_PEMA_2021_8000_8000.tif
# Loaded image 401 of 1000: split_25002690PAS_PEMA_2021_0_0.tif
# Loaded image 402 of 1000: split_25002690PAS_PEMA_2021_0_10000.tif
# Loaded image 403 of 1000: split_25002690PAS_PEMA_2021_0_12000.tif
# Loaded image 404 of 1000: split_25002690PAS_PEMA_2021_0_14000.tif
# Loaded image 405 of 1000: split_25002690PAS_PEMA_2021_0_16000.tif
# Loaded image 406 of 1000: split_25002690PAS_PEMA_2021_0_18000.tif
# Loaded image 407 of 1000: split_25002690PAS_PEMA_2021_0_2000.tif
# Loaded image 408 of 1000: split_25002690PAS_PEMA_2021_0_4000.tif
# Loaded image 409 of 1000: split_25002690PAS_PEMA_2021_0_6000.tif
# Loaded image 410 of 1000: split_25002690PAS_PEMA_2021_0_8000.tif
# Loaded image 411 of 1000: split_25002690PAS_PEMA_2021_10000_0.tif
# Loaded image 412 of 1000: split_25002690PAS_PEMA_2021_10000_10000.tif
# Loaded image 413 of 1000: split_25002690PAS_PEMA_2021_10000_12000.tif
# Loaded image 414 of 1000: split_25002690PAS_PEMA_2021_10000_14000.tif
# Loaded image 415 of 1000: split_25002690PAS_PEMA_2021_10000_16000.tif
# Loaded image 416 of 1000: split_25002690PAS_PEMA_2021_10000_18000.tif
# Loaded image 417 of 1000: split_25002690PAS_PEMA_2021_10000_2000.tif
# Loaded image 418 of 1000: split_25002690PAS_PEMA_2021_10000_4000.tif
# Loaded image 419 of 1000: split_25002690PAS_PEMA_2021_10000_6000.tif
# Loaded image 420 of 1000: split_25002690PAS_PEMA_2021_10000_8000.tif
# Loaded image 421 of 1000: split_25002690PAS_PEMA_2021_12000_0.tif
# Loaded image 422 of 1000: split_25002690PAS_PEMA_2021_12000_10000.tif
# Loaded image 423 of 1000: split_25002690PAS_PEMA_2021_12000_12000.tif
# Loaded image 424 of 1000: split_25002690PAS_PEMA_2021_12000_14000.tif
# Loaded image 425 of 1000: split_25002690PAS_PEMA_2021_12000_16000.tif
# Loaded image 426 of 1000: split_25002690PAS_PEMA_2021_12000_18000.tif
# Loaded image 427 of 1000: split_25002690PAS_PEMA_2021_12000_2000.tif
# Loaded image 428 of 1000: split_25002690PAS_PEMA_2021_12000_4000.tif
# Loaded image 429 of 1000: split_25002690PAS_PEMA_2021_12000_6000.tif
# Loaded image 430 of 1000: split_25002690PAS_PEMA_2021_12000_8000.tif
# Loaded image 431 of 1000: split_25002690PAS_PEMA_2021_14000_0.tif
# Loaded image 432 of 1000: split_25002690PAS_PEMA_2021_14000_10000.tif
# Loaded image 433 of 1000: split_25002690PAS_PEMA_2021_14000_12000.tif
# Loaded image 434 of 1000: split_25002690PAS_PEMA_2021_14000_14000.tif
# Loaded image 435 of 1000: split_25002690PAS_PEMA_2021_14000_16000.tif
# Loaded image 436 of 1000: split_25002690PAS_PEMA_2021_14000_18000.tif
# Loaded image 437 of 1000: split_25002690PAS_PEMA_2021_14000_2000.tif
# Loaded image 438 of 1000: split_25002690PAS_PEMA_2021_14000_4000.tif
# Loaded image 439 of 1000: split_25002690PAS_PEMA_2021_14000_6000.tif
# Loaded image 440 of 1000: split_25002690PAS_PEMA_2021_14000_8000.tif
# Loaded image 441 of 1000: split_25002690PAS_PEMA_2021_16000_0.tif
# Loaded image 442 of 1000: split_25002690PAS_PEMA_2021_16000_10000.tif
# Loaded image 443 of 1000: split_25002690PAS_PEMA_2021_16000_12000.tif
# Loaded image 444 of 1000: split_25002690PAS_PEMA_2021_16000_14000.tif
# Loaded image 445 of 1000: split_25002690PAS_PEMA_2021_16000_16000.tif
# Loaded image 446 of 1000: split_25002690PAS_PEMA_2021_16000_18000.tif
# Loaded image 447 of 1000: split_25002690PAS_PEMA_2021_16000_2000.tif
# Loaded image 448 of 1000: split_25002690PAS_PEMA_2021_16000_4000.tif
# Loaded image 449 of 1000: split_25002690PAS_PEMA_2021_16000_6000.tif
# Loaded image 450 of 1000: split_25002690PAS_PEMA_2021_16000_8000.tif
# Loaded image 451 of 1000: split_25002690PAS_PEMA_2021_18000_0.tif
# Loaded image 452 of 1000: split_25002690PAS_PEMA_2021_18000_10000.tif
# Loaded image 453 of 1000: split_25002690PAS_PEMA_2021_18000_12000.tif
# Loaded image 454 of 1000: split_25002690PAS_PEMA_2021_18000_14000.tif
# Loaded image 455 of 1000: split_25002690PAS_PEMA_2021_18000_16000.tif
# Loaded image 456 of 1000: split_25002690PAS_PEMA_2021_18000_18000.tif
# Loaded image 457 of 1000: split_25002690PAS_PEMA_2021_18000_2000.tif
# Loaded image 458 of 1000: split_25002690PAS_PEMA_2021_18000_4000.tif
# Loaded image 459 of 1000: split_25002690PAS_PEMA_2021_18000_6000.tif
# Loaded image 460 of 1000: split_25002690PAS_PEMA_2021_18000_8000.tif
# Loaded image 461 of 1000: split_25002690PAS_PEMA_2021_2000_0.tif
# Loaded image 462 of 1000: split_25002690PAS_PEMA_2021_2000_10000.tif
# Loaded image 463 of 1000: split_25002690PAS_PEMA_2021_2000_12000.tif
# Loaded image 464 of 1000: split_25002690PAS_PEMA_2021_2000_14000.tif
# Loaded image 465 of 1000: split_25002690PAS_PEMA_2021_2000_16000.tif
# Loaded image 466 of 1000: split_25002690PAS_PEMA_2021_2000_18000.tif
# Loaded image 467 of 1000: split_25002690PAS_PEMA_2021_2000_2000.tif
# Loaded image 468 of 1000: split_25002690PAS_PEMA_2021_2000_4000.tif
# Loaded image 469 of 1000: split_25002690PAS_PEMA_2021_2000_6000.tif
# Loaded image 470 of 1000: split_25002690PAS_PEMA_2021_2000_8000.tif
# Loaded image 471 of 1000: split_25002690PAS_PEMA_2021_4000_0.tif
# Loaded image 472 of 1000: split_25002690PAS_PEMA_2021_4000_10000.tif
# Loaded image 473 of 1000: split_25002690PAS_PEMA_2021_4000_12000.tif
# Loaded image 474 of 1000: split_25002690PAS_PEMA_2021_4000_14000.tif
# Loaded image 475 of 1000: split_25002690PAS_PEMA_2021_4000_16000.tif
# Loaded image 476 of 1000: split_25002690PAS_PEMA_2021_4000_18000.tif
# Loaded image 477 of 1000: split_25002690PAS_PEMA_2021_4000_2000.tif
# Loaded image 478 of 1000: split_25002690PAS_PEMA_2021_4000_4000.tif
# Loaded image 479 of 1000: split_25002690PAS_PEMA_2021_4000_6000.tif
# Loaded image 480 of 1000: split_25002690PAS_PEMA_2021_4000_8000.tif
# Loaded image 481 of 1000: split_25002690PAS_PEMA_2021_6000_0.tif
# Loaded image 482 of 1000: split_25002690PAS_PEMA_2021_6000_10000.tif
# Loaded image 483 of 1000: split_25002690PAS_PEMA_2021_6000_12000.tif
# Loaded image 484 of 1000: split_25002690PAS_PEMA_2021_6000_14000.tif
# Loaded image 485 of 1000: split_25002690PAS_PEMA_2021_6000_16000.tif
# Loaded image 486 of 1000: split_25002690PAS_PEMA_2021_6000_18000.tif
# Loaded image 487 of 1000: split_25002690PAS_PEMA_2021_6000_2000.tif
# Loaded image 488 of 1000: split_25002690PAS_PEMA_2021_6000_4000.tif
# Loaded image 489 of 1000: split_25002690PAS_PEMA_2021_6000_6000.tif
# Loaded image 490 of 1000: split_25002690PAS_PEMA_2021_6000_8000.tif
# Loaded image 491 of 1000: split_25002690PAS_PEMA_2021_8000_0.tif
# Loaded image 492 of 1000: split_25002690PAS_PEMA_2021_8000_10000.tif
# Loaded image 493 of 1000: split_25002690PAS_PEMA_2021_8000_12000.tif
# Loaded image 494 of 1000: split_25002690PAS_PEMA_2021_8000_14000.tif
# Loaded image 495 of 1000: split_25002690PAS_PEMA_2021_8000_16000.tif
# Loaded image 496 of 1000: split_25002690PAS_PEMA_2021_8000_18000.tif
# Loaded image 497 of 1000: split_25002690PAS_PEMA_2021_8000_2000.tif
# Loaded image 498 of 1000: split_25002690PAS_PEMA_2021_8000_4000.tif
# Loaded image 499 of 1000: split_25002690PAS_PEMA_2021_8000_6000.tif
# Loaded image 500 of 1000: split_25002690PAS_PEMA_2021_8000_8000.tif
# Loaded image 501 of 1000: split_25002700PAS_PEMA_2021_0_0.tif
# Loaded image 502 of 1000: split_25002700PAS_PEMA_2021_0_10000.tif
# Loaded image 503 of 1000: split_25002700PAS_PEMA_2021_0_12000.tif
# Loaded image 504 of 1000: split_25002700PAS_PEMA_2021_0_14000.tif
# Loaded image 505 of 1000: split_25002700PAS_PEMA_2021_0_16000.tif
# Loaded image 506 of 1000: split_25002700PAS_PEMA_2021_0_18000.tif
# Loaded image 507 of 1000: split_25002700PAS_PEMA_2021_0_2000.tif
# Loaded image 508 of 1000: split_25002700PAS_PEMA_2021_0_4000.tif
# Loaded image 509 of 1000: split_25002700PAS_PEMA_2021_0_6000.tif
# Loaded image 510 of 1000: split_25002700PAS_PEMA_2021_0_8000.tif
# Loaded image 511 of 1000: split_25002700PAS_PEMA_2021_10000_0.tif
# Loaded image 512 of 1000: split_25002700PAS_PEMA_2021_10000_10000.tif
# Loaded image 513 of 1000: split_25002700PAS_PEMA_2021_10000_12000.tif
# Loaded image 514 of 1000: split_25002700PAS_PEMA_2021_10000_14000.tif
# Loaded image 515 of 1000: split_25002700PAS_PEMA_2021_10000_16000.tif
# Loaded image 516 of 1000: split_25002700PAS_PEMA_2021_10000_18000.tif
# Loaded image 517 of 1000: split_25002700PAS_PEMA_2021_10000_2000.tif
# Loaded image 518 of 1000: split_25002700PAS_PEMA_2021_10000_4000.tif
# Loaded image 519 of 1000: split_25002700PAS_PEMA_2021_10000_6000.tif
# Loaded image 520 of 1000: split_25002700PAS_PEMA_2021_10000_8000.tif
# Loaded image 521 of 1000: split_25002700PAS_PEMA_2021_12000_0.tif
# Loaded image 522 of 1000: split_25002700PAS_PEMA_2021_12000_10000.tif
# Loaded image 523 of 1000: split_25002700PAS_PEMA_2021_12000_12000.tif
# Loaded image 524 of 1000: split_25002700PAS_PEMA_2021_12000_14000.tif
# Loaded image 525 of 1000: split_25002700PAS_PEMA_2021_12000_16000.tif
# Loaded image 526 of 1000: split_25002700PAS_PEMA_2021_12000_18000.tif
# Loaded image 527 of 1000: split_25002700PAS_PEMA_2021_12000_2000.tif
# Loaded image 528 of 1000: split_25002700PAS_PEMA_2021_12000_4000.tif
# Loaded image 529 of 1000: split_25002700PAS_PEMA_2021_12000_6000.tif
# Loaded image 530 of 1000: split_25002700PAS_PEMA_2021_12000_8000.tif
# Loaded image 531 of 1000: split_25002700PAS_PEMA_2021_14000_0.tif
# Loaded image 532 of 1000: split_25002700PAS_PEMA_2021_14000_10000.tif
# Loaded image 533 of 1000: split_25002700PAS_PEMA_2021_14000_12000.tif
# Loaded image 534 of 1000: split_25002700PAS_PEMA_2021_14000_14000.tif
# Loaded image 535 of 1000: split_25002700PAS_PEMA_2021_14000_16000.tif
# Loaded image 536 of 1000: split_25002700PAS_PEMA_2021_14000_18000.tif
# Loaded image 537 of 1000: split_25002700PAS_PEMA_2021_14000_2000.tif
# Loaded image 538 of 1000: split_25002700PAS_PEMA_2021_14000_4000.tif
# Loaded image 539 of 1000: split_25002700PAS_PEMA_2021_14000_6000.tif
# Loaded image 540 of 1000: split_25002700PAS_PEMA_2021_14000_8000.tif
# Loaded image 541 of 1000: split_25002700PAS_PEMA_2021_16000_0.tif
# Loaded image 542 of 1000: split_25002700PAS_PEMA_2021_16000_10000.tif
# Loaded image 543 of 1000: split_25002700PAS_PEMA_2021_16000_12000.tif
# Loaded image 544 of 1000: split_25002700PAS_PEMA_2021_16000_14000.tif
# Loaded image 545 of 1000: split_25002700PAS_PEMA_2021_16000_16000.tif
# Loaded image 546 of 1000: split_25002700PAS_PEMA_2021_16000_18000.tif
# Loaded image 547 of 1000: split_25002700PAS_PEMA_2021_16000_2000.tif
# Loaded image 548 of 1000: split_25002700PAS_PEMA_2021_16000_4000.tif
# Loaded image 549 of 1000: split_25002700PAS_PEMA_2021_16000_6000.tif
# Loaded image 550 of 1000: split_25002700PAS_PEMA_2021_16000_8000.tif
# Loaded image 551 of 1000: split_25002700PAS_PEMA_2021_18000_0.tif
# Loaded image 552 of 1000: split_25002700PAS_PEMA_2021_18000_10000.tif
# Loaded image 553 of 1000: split_25002700PAS_PEMA_2021_18000_12000.tif
# Loaded image 554 of 1000: split_25002700PAS_PEMA_2021_18000_14000.tif
# Loaded image 555 of 1000: split_25002700PAS_PEMA_2021_18000_16000.tif
# Loaded image 556 of 1000: split_25002700PAS_PEMA_2021_18000_18000.tif
# Loaded image 557 of 1000: split_25002700PAS_PEMA_2021_18000_2000.tif
# Loaded image 558 of 1000: split_25002700PAS_PEMA_2021_18000_4000.tif
# Loaded image 559 of 1000: split_25002700PAS_PEMA_2021_18000_6000.tif
# Loaded image 560 of 1000: split_25002700PAS_PEMA_2021_18000_8000.tif
# Loaded image 561 of 1000: split_25002700PAS_PEMA_2021_2000_0.tif
# Loaded image 562 of 1000: split_25002700PAS_PEMA_2021_2000_10000.tif
# Loaded image 563 of 1000: split_25002700PAS_PEMA_2021_2000_12000.tif
# Loaded image 564 of 1000: split_25002700PAS_PEMA_2021_2000_14000.tif
# Loaded image 565 of 1000: split_25002700PAS_PEMA_2021_2000_16000.tif
# Loaded image 566 of 1000: split_25002700PAS_PEMA_2021_2000_18000.tif
# Loaded image 567 of 1000: split_25002700PAS_PEMA_2021_2000_2000.tif
# Loaded image 568 of 1000: split_25002700PAS_PEMA_2021_2000_4000.tif
# Loaded image 569 of 1000: split_25002700PAS_PEMA_2021_2000_6000.tif
# Loaded image 570 of 1000: split_25002700PAS_PEMA_2021_2000_8000.tif
# Loaded image 571 of 1000: split_25002700PAS_PEMA_2021_4000_0.tif
# Loaded image 572 of 1000: split_25002700PAS_PEMA_2021_4000_10000.tif
# Loaded image 573 of 1000: split_25002700PAS_PEMA_2021_4000_12000.tif
# Loaded image 574 of 1000: split_25002700PAS_PEMA_2021_4000_14000.tif
# Loaded image 575 of 1000: split_25002700PAS_PEMA_2021_4000_16000.tif
# Loaded image 576 of 1000: split_25002700PAS_PEMA_2021_4000_18000.tif
# Loaded image 577 of 1000: split_25002700PAS_PEMA_2021_4000_2000.tif
# Loaded image 578 of 1000: split_25002700PAS_PEMA_2021_4000_4000.tif
# Loaded image 579 of 1000: split_25002700PAS_PEMA_2021_4000_6000.tif
# Loaded image 580 of 1000: split_25002700PAS_PEMA_2021_4000_8000.tif
# Loaded image 581 of 1000: split_25002700PAS_PEMA_2021_6000_0.tif
# Loaded image 582 of 1000: split_25002700PAS_PEMA_2021_6000_10000.tif
# Loaded image 583 of 1000: split_25002700PAS_PEMA_2021_6000_12000.tif
# Loaded image 584 of 1000: split_25002700PAS_PEMA_2021_6000_14000.tif
# Loaded image 585 of 1000: split_25002700PAS_PEMA_2021_6000_16000.tif
# Loaded image 586 of 1000: split_25002700PAS_PEMA_2021_6000_18000.tif
# Loaded image 587 of 1000: split_25002700PAS_PEMA_2021_6000_2000.tif
# Loaded image 588 of 1000: split_25002700PAS_PEMA_2021_6000_4000.tif
# Loaded image 589 of 1000: split_25002700PAS_PEMA_2021_6000_6000.tif
# Loaded image 590 of 1000: split_25002700PAS_PEMA_2021_6000_8000.tif
# Loaded image 591 of 1000: split_25002700PAS_PEMA_2021_8000_0.tif
# Loaded image 592 of 1000: split_25002700PAS_PEMA_2021_8000_10000.tif
# Loaded image 593 of 1000: split_25002700PAS_PEMA_2021_8000_12000.tif
# Loaded image 594 of 1000: split_25002700PAS_PEMA_2021_8000_14000.tif
# Loaded image 595 of 1000: split_25002700PAS_PEMA_2021_8000_16000.tif
# Loaded image 596 of 1000: split_25002700PAS_PEMA_2021_8000_18000.tif
# Loaded image 597 of 1000: split_25002700PAS_PEMA_2021_8000_2000.tif
# Loaded image 598 of 1000: split_25002700PAS_PEMA_2021_8000_4000.tif
# Loaded image 599 of 1000: split_25002700PAS_PEMA_2021_8000_6000.tif
# Loaded image 600 of 1000: split_25002700PAS_PEMA_2021_8000_8000.tif
# Loaded image 601 of 1000: split_26002690PAS_PEMA_2021_0_0.tif
# Loaded image 602 of 1000: split_26002690PAS_PEMA_2021_0_10000.tif
# Loaded image 603 of 1000: split_26002690PAS_PEMA_2021_0_12000.tif
# Loaded image 604 of 1000: split_26002690PAS_PEMA_2021_0_14000.tif
# Loaded image 605 of 1000: split_26002690PAS_PEMA_2021_0_16000.tif
# Loaded image 606 of 1000: split_26002690PAS_PEMA_2021_0_18000.tif
# Loaded image 607 of 1000: split_26002690PAS_PEMA_2021_0_2000.tif
# Loaded image 608 of 1000: split_26002690PAS_PEMA_2021_0_4000.tif
# Loaded image 609 of 1000: split_26002690PAS_PEMA_2021_0_6000.tif
# Loaded image 610 of 1000: split_26002690PAS_PEMA_2021_0_8000.tif
# Loaded image 611 of 1000: split_26002690PAS_PEMA_2021_10000_0.tif
# Loaded image 612 of 1000: split_26002690PAS_PEMA_2021_10000_10000.tif
# Loaded image 613 of 1000: split_26002690PAS_PEMA_2021_10000_12000.tif
# Loaded image 614 of 1000: split_26002690PAS_PEMA_2021_10000_14000.tif
# Loaded image 615 of 1000: split_26002690PAS_PEMA_2021_10000_16000.tif
# Loaded image 616 of 1000: split_26002690PAS_PEMA_2021_10000_18000.tif
# Loaded image 617 of 1000: split_26002690PAS_PEMA_2021_10000_2000.tif
# Loaded image 618 of 1000: split_26002690PAS_PEMA_2021_10000_4000.tif
# Loaded image 619 of 1000: split_26002690PAS_PEMA_2021_10000_6000.tif
# Loaded image 620 of 1000: split_26002690PAS_PEMA_2021_10000_8000.tif
# Loaded image 621 of 1000: split_26002690PAS_PEMA_2021_12000_0.tif
# Loaded image 622 of 1000: split_26002690PAS_PEMA_2021_12000_10000.tif
# Loaded image 623 of 1000: split_26002690PAS_PEMA_2021_12000_12000.tif
# Loaded image 624 of 1000: split_26002690PAS_PEMA_2021_12000_14000.tif
# Loaded image 625 of 1000: split_26002690PAS_PEMA_2021_12000_16000.tif
# Loaded image 626 of 1000: split_26002690PAS_PEMA_2021_12000_18000.tif
# Loaded image 627 of 1000: split_26002690PAS_PEMA_2021_12000_2000.tif
# Loaded image 628 of 1000: split_26002690PAS_PEMA_2021_12000_4000.tif
# Loaded image 629 of 1000: split_26002690PAS_PEMA_2021_12000_6000.tif
# Loaded image 630 of 1000: split_26002690PAS_PEMA_2021_12000_8000.tif
# Loaded image 631 of 1000: split_26002690PAS_PEMA_2021_14000_0.tif
# Loaded image 632 of 1000: split_26002690PAS_PEMA_2021_14000_10000.tif
# Loaded image 633 of 1000: split_26002690PAS_PEMA_2021_14000_12000.tif
# Loaded image 634 of 1000: split_26002690PAS_PEMA_2021_14000_14000.tif
# Loaded image 635 of 1000: split_26002690PAS_PEMA_2021_14000_16000.tif
# Loaded image 636 of 1000: split_26002690PAS_PEMA_2021_14000_18000.tif
# Loaded image 637 of 1000: split_26002690PAS_PEMA_2021_14000_2000.tif
# Loaded image 638 of 1000: split_26002690PAS_PEMA_2021_14000_4000.tif
# Loaded image 639 of 1000: split_26002690PAS_PEMA_2021_14000_6000.tif
# Loaded image 640 of 1000: split_26002690PAS_PEMA_2021_14000_8000.tif
# Loaded image 641 of 1000: split_26002690PAS_PEMA_2021_16000_0.tif
# Loaded image 642 of 1000: split_26002690PAS_PEMA_2021_16000_10000.tif
# Loaded image 643 of 1000: split_26002690PAS_PEMA_2021_16000_12000.tif
# Loaded image 644 of 1000: split_26002690PAS_PEMA_2021_16000_14000.tif
# Loaded image 645 of 1000: split_26002690PAS_PEMA_2021_16000_16000.tif
# Loaded image 646 of 1000: split_26002690PAS_PEMA_2021_16000_18000.tif
# Loaded image 647 of 1000: split_26002690PAS_PEMA_2021_16000_2000.tif
# Loaded image 648 of 1000: split_26002690PAS_PEMA_2021_16000_4000.tif
# Loaded image 649 of 1000: split_26002690PAS_PEMA_2021_16000_6000.tif
# Loaded image 650 of 1000: split_26002690PAS_PEMA_2021_16000_8000.tif
# Loaded image 651 of 1000: split_26002690PAS_PEMA_2021_18000_0.tif
# Loaded image 652 of 1000: split_26002690PAS_PEMA_2021_18000_10000.tif
# Loaded image 653 of 1000: split_26002690PAS_PEMA_2021_18000_12000.tif
# Loaded image 654 of 1000: split_26002690PAS_PEMA_2021_18000_14000.tif
# Loaded image 655 of 1000: split_26002690PAS_PEMA_2021_18000_16000.tif
# Loaded image 656 of 1000: split_26002690PAS_PEMA_2021_18000_18000.tif
# Loaded image 657 of 1000: split_26002690PAS_PEMA_2021_18000_2000.tif
# Loaded image 658 of 1000: split_26002690PAS_PEMA_2021_18000_4000.tif
# Loaded image 659 of 1000: split_26002690PAS_PEMA_2021_18000_6000.tif
# Loaded image 660 of 1000: split_26002690PAS_PEMA_2021_18000_8000.tif
# Loaded image 661 of 1000: split_26002690PAS_PEMA_2021_2000_0.tif
# Loaded image 662 of 1000: split_26002690PAS_PEMA_2021_2000_10000.tif
# Loaded image 663 of 1000: split_26002690PAS_PEMA_2021_2000_12000.tif
# Loaded image 664 of 1000: split_26002690PAS_PEMA_2021_2000_14000.tif
# Loaded image 665 of 1000: split_26002690PAS_PEMA_2021_2000_16000.tif
# Loaded image 666 of 1000: split_26002690PAS_PEMA_2021_2000_18000.tif
# Loaded image 667 of 1000: split_26002690PAS_PEMA_2021_2000_2000.tif
# Loaded image 668 of 1000: split_26002690PAS_PEMA_2021_2000_4000.tif
# Loaded image 669 of 1000: split_26002690PAS_PEMA_2021_2000_6000.tif
# Loaded image 670 of 1000: split_26002690PAS_PEMA_2021_2000_8000.tif
# Loaded image 671 of 1000: split_26002690PAS_PEMA_2021_4000_0.tif
# Loaded image 672 of 1000: split_26002690PAS_PEMA_2021_4000_10000.tif
# Loaded image 673 of 1000: split_26002690PAS_PEMA_2021_4000_12000.tif
# Loaded image 674 of 1000: split_26002690PAS_PEMA_2021_4000_14000.tif
# Loaded image 675 of 1000: split_26002690PAS_PEMA_2021_4000_16000.tif
# Loaded image 676 of 1000: split_26002690PAS_PEMA_2021_4000_18000.tif
# Loaded image 677 of 1000: split_26002690PAS_PEMA_2021_4000_2000.tif
# Loaded image 678 of 1000: split_26002690PAS_PEMA_2021_4000_4000.tif
# Loaded image 679 of 1000: split_26002690PAS_PEMA_2021_4000_6000.tif
# Loaded image 680 of 1000: split_26002690PAS_PEMA_2021_4000_8000.tif
# Loaded image 681 of 1000: split_26002690PAS_PEMA_2021_6000_0.tif
# Loaded image 682 of 1000: split_26002690PAS_PEMA_2021_6000_10000.tif
# Loaded image 683 of 1000: split_26002690PAS_PEMA_2021_6000_12000.tif
# Loaded image 684 of 1000: split_26002690PAS_PEMA_2021_6000_14000.tif
# Loaded image 685 of 1000: split_26002690PAS_PEMA_2021_6000_16000.tif
# Loaded image 686 of 1000: split_26002690PAS_PEMA_2021_6000_18000.tif
# Loaded image 687 of 1000: split_26002690PAS_PEMA_2021_6000_2000.tif
# Loaded image 688 of 1000: split_26002690PAS_PEMA_2021_6000_4000.tif
# Loaded image 689 of 1000: split_26002690PAS_PEMA_2021_6000_6000.tif
# Loaded image 690 of 1000: split_26002690PAS_PEMA_2021_6000_8000.tif
# Loaded image 691 of 1000: split_26002690PAS_PEMA_2021_8000_0.tif
# Loaded image 692 of 1000: split_26002690PAS_PEMA_2021_8000_10000.tif
# Loaded image 693 of 1000: split_26002690PAS_PEMA_2021_8000_12000.tif
# Loaded image 694 of 1000: split_26002690PAS_PEMA_2021_8000_14000.tif
# Loaded image 695 of 1000: split_26002690PAS_PEMA_2021_8000_16000.tif
# Loaded image 696 of 1000: split_26002690PAS_PEMA_2021_8000_18000.tif
# Loaded image 697 of 1000: split_26002690PAS_PEMA_2021_8000_2000.tif
# Loaded image 698 of 1000: split_26002690PAS_PEMA_2021_8000_4000.tif
# Loaded image 699 of 1000: split_26002690PAS_PEMA_2021_8000_6000.tif
# Loaded image 700 of 1000: split_26002690PAS_PEMA_2021_8000_8000.tif
# Loaded image 701 of 1000: split_26002710PAS_PEMA_2021_0_0.tif
# Loaded image 702 of 1000: split_26002710PAS_PEMA_2021_0_10000.tif
# Loaded image 703 of 1000: split_26002710PAS_PEMA_2021_0_12000.tif
# ...
# Loaded image 786 of 1000: split_26002710PAS_PEMA_2021_label_6000_18000.tif
# Loaded image 787 of 1000: split_26002710PAS_PEMA_2021_label_6000_2000.tif
# Loaded image 788 of 1000: split_26002710PAS_PEMA_2021_label_6000_4000.tif
# Loaded image 789 of 1000: split_26002710PAS_PEMA_2021_label_6000_6000.tif
# Loaded image 790 of 1000: split_26002710PAS_PEMA_2021_label_6000_8000.tif
# Loaded image 791 of 1000: split_26002710PAS_PEMA_2021_label_8000_0.tif
# Loaded image 792 of 1000: split_26002710PAS_PEMA_2021_label_8000_10000.tif
# Loaded image 793 of 1000: split_26002710PAS_PEMA_2021_label_8000_12000.tif
# Loaded image 794 of 1000: split_26002710PAS_PEMA_2021_label_8000_14000.tif
# Loaded image 795 of 1000: split_26002710PAS_PEMA_2021_label_8000_16000.tif
# Loaded image 796 of 1000: split_26002710PAS_PEMA_2021_label_8000_18000.tif
# Loaded image 797 of 1000: split_26002710PAS_PEMA_2021_label_8000_2000.tif
# Loaded image 798 of 1000: split_26002710PAS_PEMA_2021_label_8000_4000.tif
# Loaded image 799 of 1000: split_26002710PAS_PEMA_2021_label_8000_6000.tif
# Loaded image 800 of 1000: split_26002710PAS_PEMA_2021_label_8000_8000.tif
# Loaded image 801 of 1000: split_27002690PAS_PEMA_2021_label_0_0.tif
# Loaded image 802 of 1000: split_27002690PAS_PEMA_2021_label_0_10000.tif
# Loaded image 803 of 1000: split_27002690PAS_PEMA_2021_label_0_12000.tif
# Loaded image 804 of 1000: split_27002690PAS_PEMA_2021_label_0_14000.tif
# Loaded image 805 of 1000: split_27002690PAS_PEMA_2021_label_0_16000.tif
# Loaded image 806 of 1000: split_27002690PAS_PEMA_2021_label_0_18000.tif
# Loaded image 807 of 1000: split_27002690PAS_PEMA_2021_label_0_2000.tif
# Loaded image 808 of 1000: split_27002690PAS_PEMA_2021_label_0_4000.tif
# Loaded image 809 of 1000: split_27002690PAS_PEMA_2021_label_0_6000.tif
# Loaded image 810 of 1000: split_27002690PAS_PEMA_2021_label_0_8000.tif
# Loaded image 811 of 1000: split_27002690PAS_PEMA_2021_label_10000_0.tif
# Loaded image 812 of 1000: split_27002690PAS_PEMA_2021_label_10000_10000.tif
# Loaded image 813 of 1000: split_27002690PAS_PEMA_2021_label_10000_12000.tif
# Loaded image 814 of 1000: split_27002690PAS_PEMA_2021_label_10000_14000.tif
# Loaded image 815 of 1000: split_27002690PAS_PEMA_2021_label_10000_16000.tif
# Loaded image 816 of 1000: split_27002690PAS_PEMA_2021_label_10000_18000.tif
# Loaded image 817 of 1000: split_27002690PAS_PEMA_2021_label_10000_2000.tif
# Loaded image 818 of 1000: split_27002690PAS_PEMA_2021_label_10000_4000.tif
# Loaded image 819 of 1000: split_27002690PAS_PEMA_2021_label_10000_6000.tif
# Loaded image 820 of 1000: split_27002690PAS_PEMA_2021_label_10000_8000.tif
# Loaded image 821 of 1000: split_27002690PAS_PEMA_2021_label_12000_0.tif
# Loaded image 822 of 1000: split_27002690PAS_PEMA_2021_label_12000_10000.tif
# Loaded image 823 of 1000: split_27002690PAS_PEMA_2021_label_12000_12000.tif
# Loaded image 824 of 1000: split_27002690PAS_PEMA_2021_label_12000_14000.tif
# Loaded image 825 of 1000: split_27002690PAS_PEMA_2021_label_12000_16000.tif
# Loaded image 826 of 1000: split_27002690PAS_PEMA_2021_label_12000_18000.tif
# Loaded image 827 of 1000: split_27002690PAS_PEMA_2021_label_12000_2000.tif
# Loaded image 828 of 1000: split_27002690PAS_PEMA_2021_label_12000_4000.tif
# Loaded image 829 of 1000: split_27002690PAS_PEMA_2021_label_12000_6000.tif
# Loaded image 830 of 1000: split_27002690PAS_PEMA_2021_label_12000_8000.tif
# Loaded image 831 of 1000: split_27002690PAS_PEMA_2021_label_14000_0.tif
# Loaded image 832 of 1000: split_27002690PAS_PEMA_2021_label_14000_10000.tif
# Loaded image 833 of 1000: split_27002690PAS_PEMA_2021_label_14000_12000.tif
# Loaded image 834 of 1000: split_27002690PAS_PEMA_2021_label_14000_14000.tif
# Loaded image 835 of 1000: split_27002690PAS_PEMA_2021_label_14000_16000.tif
# Loaded image 836 of 1000: split_27002690PAS_PEMA_2021_label_14000_18000.tif
# Loaded image 837 of 1000: split_27002690PAS_PEMA_2021_label_14000_2000.tif
# Loaded image 838 of 1000: split_27002690PAS_PEMA_2021_label_14000_4000.tif
# Loaded image 839 of 1000: split_27002690PAS_PEMA_2021_label_14000_6000.tif
# Loaded image 840 of 1000: split_27002690PAS_PEMA_2021_label_14000_8000.tif
# Loaded image 841 of 1000: split_27002690PAS_PEMA_2021_label_16000_0.tif
# Loaded image 842 of 1000: split_27002690PAS_PEMA_2021_label_16000_10000.tif
# Loaded image 843 of 1000: split_27002690PAS_PEMA_2021_label_16000_12000.tif
# Loaded image 844 of 1000: split_27002690PAS_PEMA_2021_label_16000_14000.tif
# Loaded image 845 of 1000: split_27002690PAS_PEMA_2021_label_16000_16000.tif
# Loaded image 846 of 1000: split_27002690PAS_PEMA_2021_label_16000_18000.tif
# Loaded image 847 of 1000: split_27002690PAS_PEMA_2021_label_16000_2000.tif
# Loaded image 848 of 1000: split_27002690PAS_PEMA_2021_label_16000_4000.tif
# Loaded image 849 of 1000: split_27002690PAS_PEMA_2021_label_16000_6000.tif
# Loaded image 850 of 1000: split_27002690PAS_PEMA_2021_label_16000_8000.tif
# Loaded image 851 of 1000: split_27002690PAS_PEMA_2021_label_18000_0.tif
# Loaded image 852 of 1000: split_27002690PAS_PEMA_2021_label_18000_10000.tif
# Loaded image 853 of 1000: split_27002690PAS_PEMA_2021_label_18000_12000.tif
# Loaded image 854 of 1000: split_27002690PAS_PEMA_2021_label_18000_14000.tif
# Loaded image 855 of 1000: split_27002690PAS_PEMA_2021_label_18000_16000.tif
# Loaded image 856 of 1000: split_27002690PAS_PEMA_2021_label_18000_18000.tif
# Loaded image 857 of 1000: split_27002690PAS_PEMA_2021_label_18000_2000.tif
# Loaded image 858 of 1000: split_27002690PAS_PEMA_2021_label_18000_4000.tif
# Loaded image 859 of 1000: split_27002690PAS_PEMA_2021_label_18000_6000.tif
# Loaded image 860 of 1000: split_27002690PAS_PEMA_2021_label_18000_8000.tif
# Loaded image 861 of 1000: split_27002690PAS_PEMA_2021_label_2000_0.tif
# Loaded image 862 of 1000: split_27002690PAS_PEMA_2021_label_2000_10000.tif
# Loaded image 863 of 1000: split_27002690PAS_PEMA_2021_label_2000_12000.tif
# Loaded image 864 of 1000: split_27002690PAS_PEMA_2021_label_2000_14000.tif
# Loaded image 865 of 1000: split_27002690PAS_PEMA_2021_label_2000_16000.tif
# Loaded image 866 of 1000: split_27002690PAS_PEMA_2021_label_2000_18000.tif
# Loaded image 867 of 1000: split_27002690PAS_PEMA_2021_label_2000_2000.tif
# Loaded image 868 of 1000: split_27002690PAS_PEMA_2021_label_2000_4000.tif
# Loaded image 869 of 1000: split_27002690PAS_PEMA_2021_label_2000_6000.tif
# Loaded image 870 of 1000: split_27002690PAS_PEMA_2021_label_2000_8000.tif
# Loaded image 871 of 1000: split_27002690PAS_PEMA_2021_label_4000_0.tif
# Loaded image 872 of 1000: split_27002690PAS_PEMA_2021_label_4000_10000.tif
# Loaded image 873 of 1000: split_27002690PAS_PEMA_2021_label_4000_12000.tif
# Loaded image 874 of 1000: split_27002690PAS_PEMA_2021_label_4000_14000.tif
# Loaded image 875 of 1000: split_27002690PAS_PEMA_2021_label_4000_16000.tif
# Loaded image 876 of 1000: split_27002690PAS_PEMA_2021_label_4000_18000.tif
# Loaded image 877 of 1000: split_27002690PAS_PEMA_2021_label_4000_2000.tif
# Loaded image 878 of 1000: split_27002690PAS_PEMA_2021_label_4000_4000.tif
# Loaded image 879 of 1000: split_27002690PAS_PEMA_2021_label_4000_6000.tif
# Loaded image 880 of 1000: split_27002690PAS_PEMA_2021_label_4000_8000.tif
# Loaded image 881 of 1000: split_27002690PAS_PEMA_2021_label_6000_0.tif
# Loaded image 882 of 1000: split_27002690PAS_PEMA_2021_label_6000_10000.tif
# Loaded image 883 of 1000: split_27002690PAS_PEMA_2021_label_6000_12000.tif
# Loaded image 884 of 1000: split_27002690PAS_PEMA_2021_label_6000_14000.tif
# Loaded image 885 of 1000: split_27002690PAS_PEMA_2021_label_6000_16000.tif
# Loaded image 886 of 1000: split_27002690PAS_PEMA_2021_label_6000_18000.tif
# Loaded image 887 of 1000: split_27002690PAS_PEMA_2021_label_6000_2000.tif
# Loaded image 888 of 1000: split_27002690PAS_PEMA_2021_label_6000_4000.tif
# Loaded image 889 of 1000: split_27002690PAS_PEMA_2021_label_6000_6000.tif
# Loaded image 890 of 1000: split_27002690PAS_PEMA_2021_label_6000_8000.tif
# Loaded image 891 of 1000: split_27002690PAS_PEMA_2021_label_8000_0.tif
# Loaded image 892 of 1000: split_27002690PAS_PEMA_2021_label_8000_10000.tif
# Loaded image 893 of 1000: split_27002690PAS_PEMA_2021_label_8000_12000.tif
# Loaded image 894 of 1000: split_27002690PAS_PEMA_2021_label_8000_14000.tif
# Loaded image 895 of 1000: split_27002690PAS_PEMA_2021_label_8000_16000.tif
# Loaded image 896 of 1000: split_27002690PAS_PEMA_2021_label_8000_18000.tif
# Loaded image 897 of 1000: split_27002690PAS_PEMA_2021_label_8000_2000.tif
# Loaded image 898 of 1000: split_27002690PAS_PEMA_2021_label_8000_4000.tif
# Loaded image 899 of 1000: split_27002690PAS_PEMA_2021_label_8000_6000.tif
# Loaded image 900 of 1000: split_27002690PAS_PEMA_2021_label_8000_8000.tif
# Loaded image 901 of 1000: split_30002740PAS_PEMA_2021_label_0_0.tif
# Loaded image 902 of 1000: split_30002740PAS_PEMA_2021_label_0_10000.tif
# Loaded image 903 of 1000: split_30002740PAS_PEMA_2021_label_0_12000.tif
# Loaded image 904 of 1000: split_30002740PAS_PEMA_2021_label_0_14000.tif
# Loaded image 905 of 1000: split_30002740PAS_PEMA_2021_label_0_16000.tif
# Loaded image 906 of 1000: split_30002740PAS_PEMA_2021_label_0_18000.tif
# Loaded image 907 of 1000: split_30002740PAS_PEMA_2021_label_0_2000.tif
# Loaded image 908 of 1000: split_30002740PAS_PEMA_2021_label_0_4000.tif
# Loaded image 909 of 1000: split_30002740PAS_PEMA_2021_label_0_6000.tif
# Loaded image 910 of 1000: split_30002740PAS_PEMA_2021_label_0_8000.tif
# Loaded image 911 of 1000: split_30002740PAS_PEMA_2021_label_10000_0.tif
# Loaded image 912 of 1000: split_30002740PAS_PEMA_2021_label_10000_10000.tif
# Loaded image 913 of 1000: split_30002740PAS_PEMA_2021_label_10000_12000.tif
# Loaded image 914 of 1000: split_30002740PAS_PEMA_2021_label_10000_14000.tif
# Loaded image 915 of 1000: split_30002740PAS_PEMA_2021_label_10000_16000.tif
# Loaded image 916 of 1000: split_30002740PAS_PEMA_2021_label_10000_18000.tif
# Loaded image 917 of 1000: split_30002740PAS_PEMA_2021_label_10000_2000.tif
# Loaded image 918 of 1000: split_30002740PAS_PEMA_2021_label_10000_4000.tif
# Loaded image 919 of 1000: split_30002740PAS_PEMA_2021_label_10000_6000.tif
# Loaded image 920 of 1000: split_30002740PAS_PEMA_2021_label_10000_8000.tif
# Loaded image 921 of 1000: split_30002740PAS_PEMA_2021_label_12000_0.tif
# Loaded image 922 of 1000: split_30002740PAS_PEMA_2021_label_12000_10000.tif
# Loaded image 923 of 1000: split_30002740PAS_PEMA_2021_label_12000_12000.tif
# Loaded image 924 of 1000: split_30002740PAS_PEMA_2021_label_12000_14000.tif
# Loaded image 925 of 1000: split_30002740PAS_PEMA_2021_label_12000_16000.tif
# Loaded image 926 of 1000: split_30002740PAS_PEMA_2021_label_12000_18000.tif
# Loaded image 927 of 1000: split_30002740PAS_PEMA_2021_label_12000_2000.tif
# Loaded image 928 of 1000: split_30002740PAS_PEMA_2021_label_12000_4000.tif
# Loaded image 929 of 1000: split_30002740PAS_PEMA_2021_label_12000_6000.tif
# Loaded image 930 of 1000: split_30002740PAS_PEMA_2021_label_12000_8000.tif
# Loaded image 931 of 1000: split_30002740PAS_PEMA_2021_label_14000_0.tif
# Loaded image 932 of 1000: split_30002740PAS_PEMA_2021_label_14000_10000.tif
# Loaded image 933 of 1000: split_30002740PAS_PEMA_2021_label_14000_12000.tif
# Loaded image 934 of 1000: split_30002740PAS_PEMA_2021_label_14000_14000.tif
# Loaded image 935 of 1000: split_30002740PAS_PEMA_2021_label_14000_16000.tif
# Loaded image 936 of 1000: split_30002740PAS_PEMA_2021_label_14000_18000.tif
# Loaded image 937 of 1000: split_30002740PAS_PEMA_2021_label_14000_2000.tif
# Loaded image 938 of 1000: split_30002740PAS_PEMA_2021_label_14000_4000.tif
# Loaded image 939 of 1000: split_30002740PAS_PEMA_2021_label_14000_6000.tif
# Loaded image 940 of 1000: split_30002740PAS_PEMA_2021_label_14000_8000.tif
# Loaded image 941 of 1000: split_30002740PAS_PEMA_2021_label_16000_0.tif
# Loaded image 942 of 1000: split_30002740PAS_PEMA_2021_label_16000_10000.tif
# Loaded image 943 of 1000: split_30002740PAS_PEMA_2021_label_16000_12000.tif
# Loaded image 944 of 1000: split_30002740PAS_PEMA_2021_label_16000_14000.tif
# Loaded image 945 of 1000: split_30002740PAS_PEMA_2021_label_16000_16000.tif
# Loaded image 946 of 1000: split_30002740PAS_PEMA_2021_label_16000_18000.tif
# Loaded image 947 of 1000: split_30002740PAS_PEMA_2021_label_16000_2000.tif
# Loaded image 948 of 1000: split_30002740PAS_PEMA_2021_label_16000_4000.tif
# Loaded image 949 of 1000: split_30002740PAS_PEMA_2021_label_16000_6000.tif
# Loaded image 950 of 1000: split_30002740PAS_PEMA_2021_label_16000_8000.tif
# Loaded image 951 of 1000: split_30002740PAS_PEMA_2021_label_18000_0.tif
# Loaded image 952 of 1000: split_30002740PAS_PEMA_2021_label_18000_10000.tif
# Loaded image 953 of 1000: split_30002740PAS_PEMA_2021_label_18000_12000.tif
# Loaded image 954 of 1000: split_30002740PAS_PEMA_2021_label_18000_14000.tif
# Loaded image 955 of 1000: split_30002740PAS_PEMA_2021_label_18000_16000.tif
# Loaded image 956 of 1000: split_30002740PAS_PEMA_2021_label_18000_18000.tif
# Loaded image 957 of 1000: split_30002740PAS_PEMA_2021_label_18000_2000.tif
# Loaded image 958 of 1000: split_30002740PAS_PEMA_2021_label_18000_4000.tif
# Loaded image 959 of 1000: split_30002740PAS_PEMA_2021_label_18000_6000.tif
# Loaded image 960 of 1000: split_30002740PAS_PEMA_2021_label_18000_8000.tif
# Loaded image 961 of 1000: split_30002740PAS_PEMA_2021_label_2000_0.tif
# Loaded image 962 of 1000: split_30002740PAS_PEMA_2021_label_2000_10000.tif
# Loaded image 963 of 1000: split_30002740PAS_PEMA_2021_label_2000_12000.tif
# Loaded image 964 of 1000: split_30002740PAS_PEMA_2021_label_2000_14000.tif
# Loaded image 965 of 1000: split_30002740PAS_PEMA_2021_label_2000_16000.tif
# Loaded image 966 of 1000: split_30002740PAS_PEMA_2021_label_2000_18000.tif
# Loaded image 967 of 1000: split_30002740PAS_PEMA_2021_label_2000_2000.tif
# Loaded image 968 of 1000: split_30002740PAS_PEMA_2021_label_2000_4000.tif
# Loaded image 969 of 1000: split_30002740PAS_PEMA_2021_label_2000_6000.tif
# Loaded image 970 of 1000: split_30002740PAS_PEMA_2021_label_2000_8000.tif
# Loaded image 971 of 1000: split_30002740PAS_PEMA_2021_label_4000_0.tif
# Loaded image 972 of 1000: split_30002740PAS_PEMA_2021_label_4000_10000.tif
# Loaded image 973 of 1000: split_30002740PAS_PEMA_2021_label_4000_12000.tif
# Loaded image 974 of 1000: split_30002740PAS_PEMA_2021_label_4000_14000.tif
# Loaded image 975 of 1000: split_30002740PAS_PEMA_2021_label_4000_16000.tif
# Loaded image 976 of 1000: split_30002740PAS_PEMA_2021_label_4000_18000.tif
# Loaded image 977 of 1000: split_30002740PAS_PEMA_2021_label_4000_2000.tif
# Loaded image 978 of 1000: split_30002740PAS_PEMA_2021_label_4000_4000.tif
# Loaded image 979 of 1000: split_30002740PAS_PEMA_2021_label_4000_6000.tif
# Loaded image 980 of 1000: split_30002740PAS_PEMA_2021_label_4000_8000.tif
# Loaded image 981 of 1000: split_30002740PAS_PEMA_2021_label_6000_0.tif
# Loaded image 982 of 1000: split_30002740PAS_PEMA_2021_label_6000_10000.tif
# Loaded image 983 of 1000: split_30002740PAS_PEMA_2021_label_6000_12000.tif
# Loaded image 984 of 1000: split_30002740PAS_PEMA_2021_label_6000_14000.tif
# Loaded image 985 of 1000: split_30002740PAS_PEMA_2021_label_6000_16000.tif
# Loaded image 986 of 1000: split_30002740PAS_PEMA_2021_label_6000_18000.tif
# Loaded image 987 of 1000: split_30002740PAS_PEMA_2021_label_6000_2000.tif
# Loaded image 988 of 1000: split_30002740PAS_PEMA_2021_label_6000_4000.tif
# Loaded image 989 of 1000: split_30002740PAS_PEMA_2021_label_6000_6000.tif
# Loaded image 990 of 1000: split_30002740PAS_PEMA_2021_label_6000_8000.tif
# Loaded image 991 of 1000: split_30002740PAS_PEMA_2021_label_8000_0.tif
# Loaded image 992 of 1000: split_30002740PAS_PEMA_2021_label_8000_10000.tif
# Loaded image 993 of 1000: split_30002740PAS_PEMA_2021_label_8000_12000.tif
# Loaded image 994 of 1000: split_30002740PAS_PEMA_2021_label_8000_14000.tif
# Loaded image 995 of 1000: split_30002740PAS_PEMA_2021_label_8000_16000.tif
# Loaded image 996 of 1000: split_30002740PAS_PEMA_2021_label_8000_18000.tif
# Loaded image 997 of 1000: split_30002740PAS_PEMA_2021_label_8000_2000.tif
# Loaded image 998 of 1000: split_30002740PAS_PEMA_2021_label_8000_4000.tif
# Loaded image 999 of 1000: split_30002740PAS_PEMA_2021_label_8000_6000.tif
# Loaded image 1000 of 1000: split_30002740PAS_PEMA_2021_label_8000_8000.tif

# %% [markdown]
# Image Augmentation work to get more train dataset

# %%
def augment_images_and_labels(images, labels, augmentations_list, seed=None):
    ia.seed(seed if seed is not None else np.random.randint(0, 1000))

    augmented_images, augmented_labels = [], []
    for image, label in zip(images, labels):
        for augmentations in augmentations_list:
            seq = iaa.Sequential(augmentations)
            aug_image, aug_label = seq(image=image, segmentation_maps=ia.SegmentationMapsOnImage(label.squeeze(), shape=image.shape))
            augmented_images.append(aug_image)
            augmented_labels.append(aug_label.get_arr())

    # Convert augmented data to numpy arrays
    augmented_images = np.array(augmented_images)
    augmented_labels = np.array(augmented_labels)[..., np.newaxis]

    # Concatenate original and augmented data
    combined_images = np.concatenate((images, augmented_images), axis=0)
    combined_labels = np.concatenate((labels, augmented_labels), axis=0)

    return combined_images, combined_labels

# Define augmentation pipeline
# Define augmentation pipelines
augmentations_list = [
    [
        iaa.Fliplr(0.5),  # Flip images horizontally with a 50% chance
    ],
    [
        iaa.Flipud(0.5),  # Flip images vertically with a 50% chance
    ],
    [
        iaa.Affine(
            rotate=(-10, 10),  # Rotate images by -10 to +10 degrees
        ),
    ],
    [
        iaa.SomeOf((0, 2), [
            iaa.GaussianBlur(sigma=(0, 0.5)),  # Apply Gaussian blur with a sigma between 0 and 0.5
            iaa.Multiply((0.8, 1.2), per_channel=0.2),  # Change brightness of images (80-120% of original value)
        ])
    ]
]

# Apply augmentation to selected_images and selected_labels
combined_images, combined_labels = augment_images_and_labels(selected_images, selected_labels, augmentations_list)

# Print first 5 file names, dataset shapes, selected dataset shapes, and combined dataset shapes
print("First 5 image file names:", image_files[:5])
print("First 5 label file names:", label_files[:5])
print("Images shape:", images.shape)
print("Labels shape:", labels.shape)
print("Selected images:", len(selected_indices))
print("Selected images shape:", selected_images.shape)
print("Selected labels shape:", selected_labels.shape)
print("Combined images shape:", combined_images.shape)
print("Combined labels shape:", combined_labels.shape)
# Out:
# c:\Users\vestalk\anaconda3\envs\conda_musa650\lib\site-packages\imgaug\imgaug.py:106: DeprecationWarning: Got a float array as the segmentation map in SegmentationMapsOnImage. That is deprecated. Please provide instead a (H,W,[C]) array of dtype bool_, int or uint, where C denotes the segmentation map index.
#   warn(msg, category=DeprecationWarning, stacklevel=stacklevel)
# First 5 image file names: ['split_22002670PAS_PEMA_2021_0_0.tif', 'split_22002670PAS_PEMA_2021_0_10000.tif', 'split_22002670PAS_PEMA_2021_0_12000.tif', 'split_22002670PAS_PEMA_2021_0_14000.tif', 'split_22002670PAS_PEMA_2021_0_16000.tif']
# First 5 label file names: ['split_22002670PAS_PEMA_2021_label_0_0.tif', 'split_22002670PAS_PEMA_2021_label_0_10000.tif', 'split_22002670PAS_PEMA_2021_label_0_12000.tif', 'split_22002670PAS_PEMA_2021_label_0_14000.tif', 'split_22002670PAS_PEMA_2021_label_0_16000.tif']
# Images shape: (1000, 2000, 2000, 3)
# Labels shape: (1000, 2000, 2000, 1)
# Selected images: 282
# Selected images shape: (282, 2000, 2000, 3)
# Selected labels shape: (282, 2000, 2000, 1)
# Combined images shape: (1410, 2000, 2000, 3)
# Combined labels shape: (1410, 2000, 2000, 1)

# %%
def plot_augmented_images(images, labels, augmentations_list):
    n_images = len(images)
    n_augmentations = len(augmentations_list)
    fig, axes = plt.subplots(n_images, n_augmentations + 1, figsize=(20, 5 * n_images))
    
    for img_idx, (image, label) in enumerate(zip(images, labels)):
        # Plot original image and label
        axes[img_idx, 0].imshow(image)
        axes[img_idx, 0].set_title(f"Original Image {img_idx+1}")
        axes[img_idx, 0].axis("off")
        axes[img_idx, 0].imshow(label.squeeze(), alpha=0.5, cmap="gray")
        
        # Apply augmentations and plot results
        for i, augmentations in enumerate(augmentations_list):
            seq = iaa.Sequential(augmentations)
            aug_image, aug_label = seq(image=image, segmentation_maps=ia.SegmentationMapsOnImage(label.squeeze(), shape=image.shape))
            
            axes[img_idx, i+1].imshow(aug_image)
            axes[img_idx, i+1].set_title(f"Augmented Image {i+1}")
            axes[img_idx, i+1].axis("off")
            axes[img_idx, i+1].imshow(aug_label.get_arr(), alpha=0.5, cmap="gray")
    
    plt.tight_layout()
    plt.show()

# Choose multiple images and labels for demonstration
demo_images = selected_images[90:101]
demo_labels = selected_labels[90:101]

# Plot augmentation results
plot_augmented_images(demo_images, demo_labels, augmentations_list)

# %%
# Check the image and label pairs

import matplotlib.pyplot as plt

def plot_image_and_label(images, labels, index, ax):
    ax[0].imshow(images[index])
    ax[0].set_title(f"Image {index+1}")

    ax[1].imshow(labels[index].squeeze(), cmap="gray")
    ax[1].set_title(f"Label {index+1}")

# Plot 20 image and label pairs with 5 pairs per column
num_pairs_to_plot = 50
num_columns = 5
num_rows = num_pairs_to_plot // num_columns

fig, axes = plt.subplots(num_rows * 2, num_columns, figsize=(15, num_rows * 6))

for i in range(num_pairs_to_plot):
    row = i // num_columns
    col = i % num_columns
    plot_image_and_label(combined_images, combined_labels, i, (axes[row * 2, col], axes[row * 2 + 1, col]))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Split train & val sets to 80:20

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

# Split data into training and validation sets
split_index = int(0.8 * len(combined_images))
train_images, train_labels = combined_images[:split_index], combined_labels[:split_index]
val_images, val_labels = combined_images[split_index:], combined_labels[split_index:]

print(train_images.shape)
print(val_images.shape)
# Out:
# (1128, 2000, 2000, 3)
# (282, 2000, 2000, 3)

# %%
import matplotlib.pyplot as plt

def plot_image_and_label(images, labels, index, ax):
    ax[0].imshow(images[index])
    ax[0].set_title(f"Image {index+1}")

    ax[1].imshow(labels[index].squeeze(), cmap="gray")
    ax[1].set_title(f"Label {index+1}")

# Plot 20 image and label pairs with 5 pairs per column
num_pairs_to_plot = 20
num_columns = 5
num_rows = num_pairs_to_plot // num_columns

fig, axes = plt.subplots(num_rows * 2, num_columns, figsize=(15, num_rows * 6))

for i in range(num_pairs_to_plot):
    row = i // num_columns
    col = i % num_columns
    plot_image_and_label(train_images, train_labels, i, (axes[row * 2, col], axes[row * 2 + 1, col]))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Resize image to 512*512

# %%
import cv2
import gc

# Function to resize data
def resize_data(data, new_shape):
    resized_data = []
    for img in data:
        resized_img = cv2.resize(img, (new_shape[1], new_shape[0]), interpolation=cv2.INTER_NEAREST)
        resized_data.append(resized_img)
    return np.array(resized_data)

# Resize images and labels
new_shape = (512, 512, 3)
train_images_resized = resize_data(train_images, new_shape)
val_images_resized = resize_data(val_images, new_shape)

train_labels_resized = resize_data(train_labels, (new_shape[0], new_shape[1]))
val_labels_resized = resize_data(val_labels, (new_shape[0], new_shape[1]))

# Free up memory
del images
del labels
del train_images
del val_images
del train_labels
del val_labels


gc.collect()

print(train_images_resized.shape)
print(val_images_resized.shape)
print(train_labels_resized.shape)
print(val_labels_resized.shape)
# Out:
# (1128, 512, 512, 3)
# (282, 512, 512, 3)
# (1128, 512, 512)
# (282, 512, 512)

# %%
import matplotlib.pyplot as plt

def plot_image_and_label(images, labels, index, ax):
    ax[0].imshow(images[index])
    ax[0].set_title(f"Image {index+1}")

    ax[1].imshow(labels[index].squeeze(), cmap="gray")
    ax[1].set_title(f"Label {index+1}")

# Plot 20 image and label pairs with 5 pairs per column
num_pairs_to_plot = 20
num_columns = 5
num_rows = num_pairs_to_plot // num_columns

fig, axes = plt.subplots(num_rows * 2, num_columns, figsize=(15, num_rows * 6))

for i in range(num_pairs_to_plot):
    row = i // num_columns
    col = i % num_columns
    plot_image_and_label(train_images_resized, train_labels_resized, i, (axes[row * 2, col], axes[row * 2 + 1, col]))

plt.tight_layout()
plt.show()
